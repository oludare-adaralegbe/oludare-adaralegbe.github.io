# %%
import pandas as pd
import seaborn as sns
from googleapiclient.discovery import build
import math
import pprint

# %% [markdown]
# ## 1. Importing project data and extracting relevant string

# %%
# Reading csv file
df = pd.read_csv('youtube_data_united-kingdom.csv')

# Extracting the string after the '@' symbol
df['Channel_ID'] = df['NOMBRE'].str.split('@').str[1].str.strip()
df['Channel_name'] = df['NOMBRE'].str.split('@').str[0].str.strip()
df
# Out:
#       #                                       NOMBRE SEGUIDORES    TP  \
# 0     1  NoCopyrightSounds @UC_aEa8K-EOJ3D6gOs7HcyNg      32.9M     -
# 1     2             DanTDM @UCS5Oz6CHmeoF7vSad0qqXfw      26.3M     -
# 2     3                KSI @UCVtFOytbRpEvzLjvqGG5gxQ        24M     -
# 3     4         Mister Max @UC_8PAD0Qmi6_gpe77S1Atgg        23M  0.1%
# 4     5              Jelly @UC0DZmkupLYwc0yDsfocLh0A      22.9M     -
# ..  ...                                          ...        ...   ...
# 95   96               Wisp @UC0h07r_UgTD0Tc-Dn5XLX3g       4.7M  1.1%
# 96   97             WillNE @UCaFUrR3oSxOl5Y9y6tvLTEg       4.7M  2.4%
# 97   98             Zerkaa @UChntGq8THlUokhc1tT-M2wA       4.7M  2.3%
# 98   99       Ben Phillips @UChoQQRDf-zU1h6_YjKkWvdw       4.6M     -
# 99  100         Roxxsaurus @UCBKFH7bU2ebvO68FtuGjyyw       4.5M     -
#
#                 PAÍS TEMA DE INFLUENCIA ALCANCE POTENCIAL  GUARDAR  \
# 0        Reino Unido             Música              9.9M      NaN
# 1        Reino Unido                NaN              7.9M      NaN
# 2        Reino Unido                NaN              7.2M      NaN
# 3        Reino Unido                NaN              6.9M      NaN
# 4        Reino Unido                NaN              6.9M      NaN
# ..               ...                ...               ...      ...
# 95  संयुक्त अधिराज्य                NaN              1.4M      NaN
# 96  संयुक्त अधिराज्य                NaN              1.4M      NaN
# 97  संयुक्त अधिराज्य                NaN              1.4M      NaN
# 98  संयुक्त अधिराज्य                NaN              1.4M      NaN
# 99  संयुक्त अधिराज्य                NaN              1.4M      NaN
#
#    INVITAR A LA CAMPAÑA                Channel_ID       Channel_name
# 0            Ver Perfil  UC_aEa8K-EOJ3D6gOs7HcyNg  NoCopyrightSounds
# 1            Ver Perfil  UCS5Oz6CHmeoF7vSad0qqXfw             DanTDM
# 2            Ver Perfil  UCVtFOytbRpEvzLjvqGG5gxQ                KSI
# 3            Ver Perfil  UC_8PAD0Qmi6_gpe77S1Atgg         Mister Max
# 4            Ver Perfil  UC0DZmkupLYwc0yDsfocLh0A              Jelly
# ..                  ...                       ...                ...
# 95      प्रोफ़ाइल देखें  UC0h07r_UgTD0Tc-Dn5XLX3g               Wisp
# 96      प्रोफ़ाइल देखें  UCaFUrR3oSxOl5Y9y6tvLTEg             WillNE
# 97      प्रोफ़ाइल देखें  UChntGq8THlUokhc1tT-M2wA             Zerkaa
# 98      प्रोफ़ाइल देखें  UChoQQRDf-zU1h6_YjKkWvdw       Ben Phillips
# 99      प्रोफ़ाइल देखें  UCBKFH7bU2ebvO68FtuGjyyw         Roxxsaurus
#
# [100 rows x 11 columns]

# %% [markdown]
# ## 2. Preparing data for extraction

# %%
# Filtering the 'Channel_ID' column to display IDs that do not start with 'UC'
filtered_df = df[~df['Channel_ID'].str.startswith('UC')]
filtered_df
# Out:
#      #                     NOMBRE SEGUIDORES    TP              PAÍS  \
# 10  11           Sidemen @sidemen        17M  2.8%       Reino Unido
# 35  36    Julius Dein @juliusdein       9.2M     -  संयुक्त अधिराज्य
# 44  45  Liverpool FC @liverpoolfc         8M     -  संयुक्त अधिराज्य
# 79  80    ChrisMD @sirhcchris2010       5.6M  2.2%  संयुक्त अधिराज्य
# 90  91       TheDadLab @thedadlab         5M     -  संयुक्त अधिराज्य
#
#    TEMA DE INFLUENCIA ALCANCE POTENCIAL  GUARDAR INVITAR A LA CAMPAÑA  \
# 10                NaN              5.1M      NaN           Ver Perfil
# 35                NaN              2.8M      NaN      प्रोफ़ाइल देखें
# 44                NaN              2.4M      NaN      प्रोफ़ाइल देखें
# 79                NaN              1.7M      NaN      प्रोफ़ाइल देखें
# 90                NaN              1.5M      NaN      प्रोफ़ाइल देखें
#
#         Channel_ID  Channel_name
# 10         sidemen       Sidemen
# 35      juliusdein   Julius Dein
# 44     liverpoolfc  Liverpool FC
# 79  sirhcchris2010       ChrisMD
# 90       thedadlab     TheDadLab

# %%
# Dictionary of replacements
replacements = {
    'sidemen': 'UCDogdKl7t7NHzQ95aEwkdMw',
    'juliusdein': 'UCCNaMMlI3cOc7yFg52riTqg',
    'liverpoolfc': 'UC9LQwHZoucFT94I2h6JOcjw',
    'sirhcchris2010': 'UCQ-YJstgVdAiCT52TiBWDbg',
    'thedadlab': 'UCc_-hy0u9-oKlNdMKHBudcQ'
}

# Replacing custom IDs with YouTube unique IDs in 'Channel_ID' column
df['Channel_ID'] = df['Channel_ID'].replace(replacements)

# %% [markdown]
# ## 3. Extracting YouTube channel statistics

# %%
# YouTube API configuration
api_service_name = "youtube"
api_version = "v3"
youtube_api_key = 'YOUR_API_KEY'

# Converting the Channel_ID column to a list
channel_ids = df['Channel_ID'].tolist()

# Build the YouTube service
youtube = build(api_service_name, api_version, developerKey=youtube_api_key)

# %%
channel_id = 'UCc_-hy0u9-oKlNdMKHBudcQ'

def get_channel_stats(youtube, channel_id):
        
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=channel_id)

    response = request.execute()

    return response

# %%
get_channel_stats(youtube, channel_id)
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'NzKUJUWCPEWjeJXhlDNlHN-jJBE',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'OFQkYc68gRWsRh0B_s65MekAUKQ',
#    'id': 'UCc_-hy0u9-oKlNdMKHBudcQ',
#    'snippet': {'title': 'TheDadLab',
#     'description': 'Kids Science Experiments and Interactive activities to do at home\n\nI’m Sergei 👋 father of two adorable boys: Alex and Max. I love spending time with my kids and teaching them how to think creatively while having fun doing it. \n\nWe love experimenting with the coolest science activities, fun educational toys, building sets, wooden toys, activity books and creative paper crafts. \n\nSubscribe for access to weekly DIY science activities you can do at home! http://bit.ly/ThedadlabOnYoutube\n\nFollow my fatherhood journey.\nFACEBOOK https://www.facebook.com/thedadlab\nTWITTER https://twitter.com/thedadlab\nINSTAGRAM https://www.instagram.com/thedadlab\nTIKTOK https://www.tiktok.com/@thedadlab\nWebsite https://thedadlab.com\n\nCheck out these popular videos!\nhttps://www.youtube.com/watch?v=Kv5ZI6p6szg&list=PLqChB1IXCYBdK5TAovTqLahHu66zUzBcW\n\n\n #thedadlab #scienceexperiements #scienceforkids\n\nFor business enquiries, please contact: zach@intalentdigital.com',
#     'customUrl': '@thedadlab',
#     'publishedAt': '2016-01-06T13:09:39Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AIdro_kKKrC5qZARKGI9RERzcNOfgQiYdlwXF_sJgQV5njk7=s88-c-k-c0x00ffffff-no-rj',
#       'width': 88,
#       'height': 88},
#      'medium': {'url': 'https://yt3.ggpht.com/ytc/AIdro_kKKrC5qZARKGI9RERzcNOfgQiYdlwXF_sJgQV5njk7=s240-c-k-c0x00ffffff-no-rj',
#       'width': 240,
#       'height': 240},
#      'high': {'url': 'https://yt3.ggpht.com/ytc/AIdro_kKKrC5qZARKGI9RERzcNOfgQiYdlwXF_sJgQV5njk7=s800-c-k-c0x00ffffff-no-rj',
#       'width': 800,
#       'height': 800}},
#     'localized': {'title': 'TheDadLab',
#      'description': 'Kids Science Experiments and Interactive activities to do at home\n\nI’m Sergei 👋 father of two adorable boys: Alex and Max. I love spending time with my kids and teaching them how to think creatively while having fun doing it. \n\nWe love experimenting with the coolest science activities, fun educational toys, building sets, wooden toys, activity books and creative paper crafts. \n\nSubscribe for access to weekly DIY science activities you can do at home! http://bit.ly/ThedadlabOnYoutube\n\nFollow my fatherhood journey.\nFACEBOOK https://www.facebook.com/thedadlab\nTWITTER https://twitter.com/thedadlab\nINSTAGRAM https://www.instagram.com/thedadlab\nTIKTOK https://www.tiktok.com/@thedadlab\nWebsite https://thedadlab.com\n\nCheck out these popular videos!\nhttps://www.youtube.com/watch?v=Kv5ZI6p6szg&list=PLqChB1IXCYBdK5TAovTqLahHu66zUzBcW\n\n\n #thedadlab #scienceexperiements #scienceforkids\n\nFor business enquiries, please contact: zach@intalentdigital.com'},
#     'country': 'GB'},
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUc_-hy0u9-oKlNdMKHBudcQ'}},
#    'statistics': {'viewCount': '2959262283',
#     'subscriberCount': '5200000',
#     'hiddenSubscriberCount': False,
#     'videoCount': '832'}}]}

# %%
def chunkify(lst, n):
    """Splits the list into chunks of size n."""
    return [lst[i:i + n] for i in range(0, len(lst), n)]

def pull_channel_stats(youtube, channel_ids):
    """Fetches statistics for a list of channel IDs."""
    dataset = []
    
    # Split channel_ids into chunks of size 50
    # since the YouTube API typically allows up to 50 IDs per request
    chunked_channel_ids = chunkify(channel_ids, 50)

    # Looping over each chunk of channel IDs
    for chunk in chunked_channel_ids:
        request = youtube.channels().list(
            part="snippet,contentDetails,statistics",
            id=','.join(chunk)
        )
        response = request.execute()

        # Extracting statistics for each channel
        for item in response['items']:    
            data = dict(
                Channel_ID=item['id'],
                Channel_name=item['snippet']['title'],
                Subscribers=item['statistics']['subscriberCount'],
                Views=item['statistics']['viewCount'],
                Total_videos=item['statistics']['videoCount'],
            )
            dataset.append(data)
                
    return dataset

# %%
# Fetching and displaying statistics for all channel IDs
channel_stats = pull_channel_stats(youtube, channel_ids)
pprint.pprint(channel_stats)
# Out:
# [{'Channel_ID': 'UCLeuoGy_hUDTBf5Hk0ynrpQ',
#   'Channel_name': 'DisneyChannelUK',
#   'Subscribers': '13000000',
#   'Total_videos': '4526',
#   'Views': '13403174663'},
#  {'Channel_ID': 'UC5p_l5ZeB_wGjO_yDXwiqvw',
#   'Channel_name': 'TommyInnit',
#   'Subscribers': '14800000',
#   'Total_videos': '469',
#   'Views': '2385264194'},
#  {'Channel_ID': 'UCCj956IF62FbT7Gouszaj9w',
#   'Channel_name': 'BBC',
#   'Subscribers': '14200000',
#   'Total_videos': '19309',
#   'Views': '10468169782'},
#  {'Channel_ID': 'UCS7H8U-n5mINVJjJsaRtGHg',
#   'Channel_name': 'Shaun the Sheep Official',
#   'Subscribers': '12000000',
#   'Total_videos': '882',
#   'Views': '6416516862'},
#  {'Channel_ID': 'UC9LQwHZoucFT94I2h6JOcjw',
#   'Channel_name': 'Liverpool FC',
#   'Subscribers': '10000000',
#   'Total_videos': '6577',
#   'Views': '2780993849'},
#  {'Channel_ID': 'UC1ieoHqKW-yYgDhLHIcx28w',
#   'Channel_name': 'Syndicate',
#   'Subscribers': '9610000',
#   'Total_videos': '3530',
#   'Views': '2133867067'},
#  {'Channel_ID': 'UC0DZmkupLYwc0yDsfocLh0A',
#   'Channel_name': 'Jelly',
#   'Subscribers': '23600000',
#   'Total_videos': '6422',
#   'Views': '15083492903'},
#  {'Channel_ID': 'UC977n5nXRn8MDuGQjwxkOLw',
#   'Channel_name': 'Cartoons for Kids',
#   'Subscribers': '9010000',
#   'Total_videos': '2523',
#   'Views': '3412033155'},
#  {'Channel_ID': 'UCjOl2AUblVmg2rA_cRgZkFg',
#   'Channel_name': 'Top Gear',
#   'Subscribers': '8970000',
#   'Total_videos': '1888',
#   'Views': '3997920925'},
#  {'Channel_ID': 'UCvwgF_0NOZe2vN4Q3g1bY-A',
#   'Channel_name': 'Vikkstar123',
#   'Subscribers': '7600000',
#   'Total_videos': '5044',
#   'Views': '2161485417'},
#  {'Channel_ID': 'UCS5Oz6CHmeoF7vSad0qqXfw',
#   'Channel_name': 'DanTDM',
#   'Subscribers': '28700000',
#   'Total_videos': '3707',
#   'Views': '19824733776'},
#  {'Channel_ID': 'UC-FQUIVQ-bZiefzBiQAa8Fw',
#   'Channel_name': 'BBC Radio 1',
#   'Subscribers': '8260000',
#   'Total_videos': '4911',
#   'Views': '3737223427'},
#  {'Channel_ID': 'UCcartHVtvAUzfajflyeT_Gg',
#   'Channel_name': 'Miss Katy',
#   'Subscribers': '24600000',
#   'Total_videos': '1088',
#   'Views': '15611067290'},
#  {'Channel_ID': 'UC6D1L2vxEAg_Vi0JSxMBDgA',
#   'Channel_name': 'Dan Rhodes',
#   'Subscribers': '26900000',
#   'Total_videos': '1670',
#   'Views': '18782581258'},
#  {'Channel_ID': 'UC-0D1RlSzcvBoODCKSoLl2g',
#   'Channel_name': 'Emily Tube',
#   'Subscribers': '11100000',
#   'Total_videos': '727',
#   'Views': '3729377267'},
#  {'Channel_ID': 'UCfIXdjDQH9Fau7y99_Orpjw',
#   'Channel_name': 'Gorillaz',
#   'Subscribers': '10900000',
#   'Total_videos': '363',
#   'Views': '5869500396'},
#  {'Channel_ID': 'UCVtFOytbRpEvzLjvqGG5gxQ',
#   'Channel_name': 'KSI',
#   'Subscribers': '24100000',
#   'Total_videos': '1252',
#   'Views': '6015064768'},
#  {'Channel_ID': 'UCBq5hp6DvwWam2XOXw6lYJA',
#   'Channel_name': 'Awakening Music',
#   'Subscribers': '14100000',
#   'Total_videos': '939',
#   'Views': '5969300940'},
#  {'Channel_ID': 'UCHwBjRoGO1V-H8QYXjSVHkQ',
#   'Channel_name': 'Gaby and Alex',
#   'Subscribers': '17200000',
#   'Total_videos': '367',
#   'Views': '8686551796'},
#  {'Channel_ID': 'UCEwIUtFBhaI2L2PuKv0KL2g',
#   'Channel_name': 'Classic Mr Bean',
#   'Subscribers': '10500000',
#   'Total_videos': '1749',
#   'Views': '3417596496'},
#  {'Channel_ID': 'UC_8PAD0Qmi6_gpe77S1Atgg',
#   'Channel_name': 'Mister Max',
#   'Subscribers': '24500000',
#   'Total_videos': '1145',
#   'Views': '16070336960'},
#  {'Channel_ID': 'UC6sSkkemzPjmrzS0Y0V_2zw',
#   'Channel_name': 'Tiana',
#   'Subscribers': '11400000',
#   'Total_videos': '1039',
#   'Views': '3244898742'},
#  {'Channel_ID': 'UCKvn9VBLAiLiYL4FFJHri6g',
#   'Channel_name': 'F2Freestylers - Ultimate Soccer Skills Channel',
#   'Subscribers': '14100000',
#   'Total_videos': '781',
#   'Views': '3350393119'},
#  {'Channel_ID': 'UC16niRr50-MSBwiO3YDb3RA',
#   'Channel_name': 'BBC News',
#   'Subscribers': '16100000',
#   'Total_videos': '21791',
#   'Views': '5339002388'},
#  {'Channel_ID': 'UChUHOEe7zgYmrv7a_LlpNng',
#   'Channel_name': 'Jungle Beat',
#   'Subscribers': '11600000',
#   'Total_videos': '831',
#   'Views': '5853428511'},
#  {'Channel_ID': 'UCp68_FLety0O-n9QU6phsgw',
#   'Channel_name': 'colinfurze',
#   'Subscribers': '13000000',
#   'Total_videos': '397',
#   'Views': '1750845605'},
#  {'Channel_ID': 'UCYVinkwSX7szARULgYpvhLw',
#   'Channel_name': 'Ali-A',
#   'Subscribers': '18900000',
#   'Total_videos': '4350',
#   'Views': '6509983851'},
#  {'Channel_ID': 'UC-J-KZfRV8c13fOCkhXdLiQ',
#   'Channel_name': 'Dua Lipa',
#   'Subscribers': '23600000',
#   'Total_videos': '270',
#   'Views': '13183103352'},
#  {'Channel_ID': 'UCiMhD4jzUqG-IgPzUmmytRQ',
#   'Channel_name': 'Queen Official',
#   'Subscribers': '17700000',
#   'Total_videos': '1181',
#   'Views': '11284694804'},
#  {'Channel_ID': 'UCIvqWqjC4aLvp7zI8hzARrA',
#   'Channel_name': 'Little Mix',
#   'Subscribers': '16400000',
#   'Total_videos': '278',
#   'Views': '7838466387'},
#  {'Channel_ID': 'UCz4tgANd4yy8Oe0iXCdSWfA',
#   'Channel_name': 'English with Lucy',
#   'Subscribers': '11000000',
#   'Total_videos': '388',
#   'Views': '505226477'},
#  {'Channel_ID': 'UCBwSufNse8VMBvQM_rCSvgQ',
#   'Channel_name': 'Morgz',
#   'Subscribers': '12700000',
#   'Total_videos': '847',
#   'Views': '3535591021'},
#  {'Channel_ID': 'UChFur_NwVSbUozOcF_F2kMg',
#   'Channel_name': 'Mumbo Jumbo',
#   'Subscribers': '9370000',
#   'Total_videos': '2079',
#   'Views': '3062421565'},
#  {'Channel_ID': 'UCHdMK5Ef2El8KbD3L_WgANg',
#   'Channel_name': 'Slogo',
#   'Subscribers': '11700000',
#   'Total_videos': '6359',
#   'Views': '8958579645'},
#  {'Channel_ID': 'UC_aEa8K-EOJ3D6gOs7HcyNg',
#   'Channel_name': 'NoCopyrightSounds',
#   'Subscribers': '33700000',
#   'Total_videos': '1665',
#   'Views': '11118688310'},
#  {'Channel_ID': 'UCDogdKl7t7NHzQ95aEwkdMw',
#   'Channel_name': 'Sidemen',
#   'Subscribers': '21200000',
#   'Total_videos': '358',
#   'Views': '6206481212'},
#  {'Channel_ID': 'UCMiJRAwDNSNzuYeN2uWa0pA',
#   'Channel_name': 'Mrwhosetheboss',
#   'Subscribers': '18800000',
#   'Total_videos': '1695',
#   'Views': '5470724046'},
#  {'Channel_ID': 'UC4pEp0mo54WhEBCTYvjVDJA',
#   'Channel_name': 'Jessie J',
#   'Subscribers': '10600000',
#   'Total_videos': '96',
#   'Views': '5795719260'},
#  {'Channel_ID': 'UC1QqdFv5e9QSEi0eYdfwuqw',
#   'Channel_name': 'Moonbug Kids - Kids Learning Videos',
#   'Subscribers': '11200000',
#   'Total_videos': '1586',
#   'Views': '8541920316'},
#  {'Channel_ID': 'UCR9Gcq0CMm6YgTzsDxAxjOQ',
#   'Channel_name': 'Grian',
#   'Subscribers': '8530000',
#   'Total_videos': '756',
#   'Views': '2463018704'},
#  {'Channel_ID': 'UCelk6aHijZq-GJBBB9YpReA',
#   'Channel_name': 'BBC News عربي',
#   'Subscribers': '11600000',
#   'Total_videos': '40825',
#   'Views': '4922625996'},
#  {'Channel_ID': 'UCDBCCMlFD-hArPbWv38FINA',
#   'Channel_name': 'Daz Games',
#   'Subscribers': '8610000',
#   'Total_videos': '1575',
#   'Views': '2721285039'},
#  {'Channel_ID': 'UCEY1ejsweY4DgMwOVJeEaBA',
#   'Channel_name': 'The X Factor UK',
#   'Subscribers': '9180000',
#   'Total_videos': '5502',
#   'Views': '7005021123'},
#  {'Channel_ID': 'UCHFA6Nt11kE_8OWIya0SQDQ',
#   'Channel_name': 'PlayToys',
#   'Subscribers': '7800000',
#   'Total_videos': '973',
#   'Views': '3056531025'},
#  {'Channel_ID': 'UCUhFaUpnq31m6TNX2VKVSVA',
#   'Channel_name': 'carwow',
#   'Subscribers': '9290000',
#   'Total_videos': '2694',
#   'Views': '3937262712'},
#  {'Channel_ID': 'UCGmnsW623G1r-Chmo5RB4Yw',
#   'Channel_name': 'JJ Olatunji',
#   'Subscribers': '16300000',
#   'Total_videos': '1354',
#   'Views': '4269931038'},
#  {'Channel_ID': 'UCoGForHQAmk0_9rI9CABeYw',
#   'Channel_name': 'Woody & Kleiny',
#   'Subscribers': '15600000',
#   'Total_videos': '1125',
#   'Views': '14393820434'},
#  {'Channel_ID': 'UCCNaMMlI3cOc7yFg52riTqg',
#   'Channel_name': 'Julius Dein',
#   'Subscribers': '9280000',
#   'Total_videos': '385',
#   'Views': '2476381778'},
#  {'Channel_ID': 'UC7Gf2tZ8coTX2ckTPgn62iQ',
#   'Channel_name': 'Disney Kids',
#   'Subscribers': '12100000',
#   'Total_videos': '2907',
#   'Views': '12411944853'},
#  {'Channel_ID': 'UCwTRjvjVge51X-ILJ4i22ew',
#   'Channel_name': 'Sing King',
#   'Subscribers': '12000000',
#   'Total_videos': '4383',
#   'Views': '7939187280'},
#  {'Channel_ID': 'UCswH8ovgUp5Bdg-0_JTYFNw',
#   'Channel_name': 'Russell Brand',
#   'Subscribers': '6800000',
#   'Total_videos': '2806',
#   'Views': '1300008675'},
#  {'Channel_ID': 'UCOYWgypDktXdb-HfZnSMK6A',
#   'Channel_name': 'TomSka',
#   'Subscribers': '7280000',
#   'Total_videos': '178',
#   'Views': '2081738129'},
#  {'Channel_ID': 'UCcmpeVbSSQlZRvHfdC-CRwg',
#   'Channel_name': '24 News HD',
#   'Subscribers': '7880000',
#   'Total_videos': '168745',
#   'Views': '3482204763'},
#  {'Channel_ID': 'UCpSgg_ECBj25s9moCDfSTsA',
#   'Channel_name': 'Jamie Oliver',
#   'Subscribers': '5940000',
#   'Total_videos': '2133',
#   'Views': '964128514'},
#  {'Channel_ID': 'UCrSx8rek9EuC3YGHvG8aalw',
#   'Channel_name': 'ARPO The Robot',
#   'Subscribers': '7700000',
#   'Total_videos': '1368',
#   'Views': '3260625865'},
#  {'Channel_ID': 'UCdcUmdOxMrhRjKMw-BX19AA',
#   'Channel_name': 'Niko Omilana',
#   'Subscribers': '7490000',
#   'Total_videos': '141',
#   'Views': '621854869'},
#  {'Channel_ID': 'UCV5Gw7GGOMxe6SSF6llp_3Q',
#   'Channel_name': 'James Arthur',
#   'Subscribers': '7410000',
#   'Total_videos': '208',
#   'Views': '4454163779'},
#  {'Channel_ID': 'UCM88mtSE0zRTn5ae4EbYcuw',
#   'Channel_name': 'Pingu - Official Channel',
#   'Subscribers': '6940000',
#   'Total_videos': '646',
#   'Views': '2823535494'},
#  {'Channel_ID': 'UC0h07r_UgTD0Tc-Dn5XLX3g',
#   'Channel_name': 'Wisp',
#   'Subscribers': '5210000',
#   'Total_videos': '524',
#   'Views': '1085810664'},
#  {'Channel_ID': 'UCzTlXb7ivVzuFlugVCv3Kvg',
#   'Channel_name': 'LDShadowLady',
#   'Subscribers': '7180000',
#   'Total_videos': '1079',
#   'Views': '3444865906'},
#  {'Channel_ID': 'UC_wITz-Ze4JFc3WLQA1n3Hw',
#   'Channel_name': 'RubyandBonnie',
#   'Subscribers': '9030000',
#   'Total_videos': '636',
#   'Views': '5257958508'},
#  {'Channel_ID': 'UCmst562fALOY2cKb4IFgqEg',
#   'Channel_name': 'Boomerang UK',
#   'Subscribers': '7370000',
#   'Total_videos': '2369',
#   'Views': '3649025003'},
#  {'Channel_ID': 'UChntGq8THlUokhc1tT-M2wA',
#   'Channel_name': 'Zerkaa',
#   'Subscribers': '4710000',
#   'Total_videos': '2021',
#   'Views': '858247303'},
#  {'Channel_ID': 'UC-VDfQNL-S44eZscGlXI14g',
#   'Channel_name': 'Dumori Bay',
#   'Subscribers': '5340000',
#   'Total_videos': '225',
#   'Views': '1130484'},
#  {'Channel_ID': 'UChoQQRDf-zU1h6_YjKkWvdw',
#   'Channel_name': 'Ben Phillips',
#   'Subscribers': '4540000',
#   'Total_videos': '860',
#   'Views': '1274000926'},
#  {'Channel_ID': 'UCrSgaO6xOY8YV1EoCbD51HA',
#   'Channel_name': 'MessYourself',
#   'Subscribers': '6870000',
#   'Total_videos': '1068',
#   'Views': '2570671210'},
#  {'Channel_ID': 'UCO66lK14MYiXlu0A6pQ4ouA',
#   'Channel_name': 'More Emily',
#   'Subscribers': '5290000',
#   'Total_videos': '634',
#   'Views': '1480566446'},
#  {'Channel_ID': 'UCqTwKvjbTENZDGbz2si47ag',
#   'Channel_name': 'GRM Daily',
#   'Subscribers': '6340000',
#   'Total_videos': '14878',
#   'Views': '7563003291'},
#  {'Channel_ID': 'UCvZwcK22QTUaM18KE7mHeNw',
#   'Channel_name': 'Max and Katy',
#   'Subscribers': '4720000',
#   'Total_videos': '508',
#   'Views': '1317068809'},
#  {'Channel_ID': 'UC7_yh9PEDpaqp34QtGO-_Yw',
#   'Channel_name': 'Tiana2',
#   'Subscribers': '5870000',
#   'Total_videos': '429',
#   'Views': '1644339875'},
#  {'Channel_ID': 'UCfLFTP1uTuIizynWsZq2nkQ',
#   'Channel_name': 'UKF Dubstep',
#   'Subscribers': '6240000',
#   'Total_videos': '1739',
#   'Views': '2126177879'},
#  {'Channel_ID': 'UCQdsJ95w9jh-yB0BA6EDGWA',
#   'Channel_name': 'Rhia Official',
#   'Subscribers': '12800000',
#   'Total_videos': '925',
#   'Views': '6003836330'},
#  {'Channel_ID': 'UCFHtCB_FWXQ8GpjgfYcD8-g',
#   'Channel_name': 'Passenger',
#   'Subscribers': '7400000',
#   'Total_videos': '387',
#   'Views': '4567686772'},
#  {'Channel_ID': 'UCu4XcDBdnZkV6-5z2f16M0g',
#   'Channel_name': 'Real Stories',
#   'Subscribers': '6320000',
#   'Total_videos': '1103',
#   'Views': '1174626206'},
#  {'Channel_ID': 'UCvxfEIG3PHpgM0TMJJ_SH-w',
#   'Channel_name': 'Jarvis',
#   'Subscribers': '5670000',
#   'Total_videos': '718',
#   'Views': '1709115914'},
#  {'Channel_ID': 'UCHaHD477h-FeBbVh9Sh7syA',
#   'Channel_name': 'BBC Learning English',
#   'Subscribers': '6610000',
#   'Total_videos': '3629',
#   'Views': '343941371'},
#  {'Channel_ID': 'UC1n_PfsVqxllCcnMPlxBIjw',
#   'Channel_name': 'Wilbur Soot',
#   'Subscribers': '5830000',
#   'Total_videos': '139',
#   'Views': '796348207'},
#  {'Channel_ID': 'UCoMdktPbSTixAyNGwb-UYkQ',
#   'Channel_name': 'Sky News',
#   'Subscribers': '7750000',
#   'Total_videos': '48257',
#   'Views': '4390574175'},
#  {'Channel_ID': 'UC5Y1pPVNm-odhiubuRO1D6A',
#   'Channel_name': 'Jeremy Lynch',
#   'Subscribers': '11900000',
#   'Total_videos': '778',
#   'Views': '6384380741'},
#  {'Channel_ID': 'UCHiceVclOIFCgAcveITRLLw',
#   'Channel_name': 'Nickelodeon UK',
#   'Subscribers': '7010000',
#   'Total_videos': '3287',
#   'Views': '7447866208'},
#  {'Channel_ID': 'UCLk9wddjT0F-HILLRFXodtg',
#   'Channel_name': 'Joe Weller',
#   'Subscribers': '5290000',
#   'Total_videos': '321',
#   'Views': '1015923732'},
#  {'Channel_ID': 'UCZSlfzadjnw7G419c_OJ9eg',
#   'Channel_name': 'Mrwhosetheboss Shorts',
#   'Subscribers': '7100000',
#   'Total_videos': '186',
#   'Views': '3749144723'},
#  {'Channel_ID': 'UCHhfSXoDG6gSgpOvLH4wrRw',
#   'Channel_name': 'Behzinga',
#   'Subscribers': '4960000',
#   'Total_videos': '872',
#   'Views': '580456254'},
#  {'Channel_ID': 'UCc_-hy0u9-oKlNdMKHBudcQ',
#   'Channel_name': 'TheDadLab',
#   'Subscribers': '5200000',
#   'Total_videos': '832',
#   'Views': '2960437143'},
#  {'Channel_ID': 'UCBKFH7bU2ebvO68FtuGjyyw',
#   'Channel_name': 'Roxxsaurus',
#   'Subscribers': '4580000',
#   'Total_videos': '950',
#   'Views': '541841284'},
#  {'Channel_ID': 'UCkzCjdRMrW2vXLx8mvPVLdQ',
#   'Channel_name': 'Man City',
#   'Subscribers': '7440000',
#   'Total_videos': '8419',
#   'Views': '2024039459'},
#  {'Channel_ID': 'UCakgsb0w7QB0VHdnCc-OVEA',
#   'Channel_name': 'Space Videos',
#   'Subscribers': '5650000',
#   'Total_videos': '139',
#   'Views': '114424800'},
#  {'Channel_ID': 'UC6yW44UGJJBvYTlfC7CRg2Q',
#   'Channel_name': 'Manchester United',
#   'Subscribers': '9010000',
#   'Total_videos': '4127',
#   'Views': '2224101603'},
#  {'Channel_ID': 'UCbmWOFTbZoDLWqG1rvFnJ0g',
#   'Channel_name': 'WildBrain Kids',
#   'Subscribers': '8750000',
#   'Total_videos': '4999',
#   'Views': '4185834669'},
#  {'Channel_ID': 'UCZzwjZPc6R_PbnDgFVMwlvQ',
#   'Channel_name': 'Capital FM',
#   'Subscribers': '6150000',
#   'Total_videos': '2572',
#   'Views': '3571544927'},
#  {'Channel_ID': 'UC2C_jShtL725hvbm1arSV9w',
#   'Channel_name': 'CGP Grey',
#   'Subscribers': '6370000',
#   'Total_videos': '189',
#   'Views': '1037570204'},
#  {'Channel_ID': 'UCH-_hzb2ILSCo9ftVSnrCIQ',
#   'Channel_name': 'The Yogscast',
#   'Subscribers': '7070000',
#   'Total_videos': '6526',
#   'Views': '4576420007'},
#  {'Channel_ID': 'UCOgUcv_9DaivXzsN9mcHIzQ',
#   'Channel_name': 'TGFbro',
#   'Subscribers': '6170000',
#   'Total_videos': '472',
#   'Views': '1463751437'},
#  {'Channel_ID': 'UCh5mLn90vUaB1PbRRx_AiaA',
#   'Channel_name': 'MoreSidemen',
#   'Subscribers': '8430000',
#   'Total_videos': '1028',
#   'Views': '4359636172'},
#  {'Channel_ID': 'UCSY5V7BJSrxNvvBF0Drslow',
#   'Channel_name': 'Mark Ronson',
#   'Subscribers': '6890000',
#   'Total_videos': '20',
#   'Views': '6587403647'},
#  {'Channel_ID': 'UCRlICXvO4XR4HMeEB9JjDlA',
#   'Channel_name': 'Thoughty2',
#   'Subscribers': '5430000',
#   'Total_videos': '825',
#   'Views': '1050329046'},
#  {'Channel_ID': 'UCaFUrR3oSxOl5Y9y6tvLTEg',
#   'Channel_name': 'WillNE',
#   'Subscribers': '5040000',
#   'Total_videos': '305',
#   'Views': '858661214'},
#  {'Channel_ID': 'UCQ-YJstgVdAiCT52TiBWDbg',
#   'Channel_name': 'ChrisMD',
#   'Subscribers': '6040000',
#   'Total_videos': '511',
#   'Views': '1564981558'},
#  {'Channel_ID': 'UCH6vXjt-BA7QHl0KnfL-7RQ',
#   'Channel_name': "Simon's Cat",
#   'Subscribers': '6240000',
#   'Total_videos': '491',
#   'Views': '1586514356'},
#  {'Channel_ID': 'UCc4K7bAqpdBP8jh1j9XZAww',
#   'Channel_name': 'The Beatles',
#   'Subscribers': '8310000',
#   'Total_videos': '317',
#   'Views': '6953481449'}]

# %%
# Convert the list of dictionaries to a DataFrame
channel_stats_df = pd.DataFrame(channel_stats)

# %%
# Converting columns from object to numeric
channel_stats_df['Subscribers'] = pd.to_numeric(channel_stats_df['Subscribers'])
channel_stats_df['Views'] = pd.to_numeric(channel_stats_df['Views'])
channel_stats_df['Total_videos'] = pd.to_numeric(channel_stats_df['Total_videos'])
channel_stats_df.dtypes
# Out:
# Channel_ID      object
# Channel_name    object
# Subscribers      int64
# Views            int64
# Total_videos     int64
# dtype: object

# %%
channel_stats_df
# Out:
#                   Channel_ID              Channel_name  Subscribers  \
# 0   UCLeuoGy_hUDTBf5Hk0ynrpQ           DisneyChannelUK     13000000
# 1   UC5p_l5ZeB_wGjO_yDXwiqvw                TommyInnit     14800000
# 2   UCCj956IF62FbT7Gouszaj9w                       BBC     14200000
# 3   UCS7H8U-n5mINVJjJsaRtGHg  Shaun the Sheep Official     12000000
# 4   UC9LQwHZoucFT94I2h6JOcjw              Liverpool FC     10000000
# ..                       ...                       ...          ...
# 95  UCRlICXvO4XR4HMeEB9JjDlA                 Thoughty2      5430000
# 96  UCaFUrR3oSxOl5Y9y6tvLTEg                    WillNE      5040000
# 97  UCQ-YJstgVdAiCT52TiBWDbg                   ChrisMD      6040000
# 98  UCH6vXjt-BA7QHl0KnfL-7RQ               Simon's Cat      6240000
# 99  UCc4K7bAqpdBP8jh1j9XZAww               The Beatles      8310000
#
#           Views  Total_videos
# 0   13403174663          4526
# 1    2385264194           469
# 2   10468169782         19309
# 3    6416516862           882
# 4    2780993849          6577
# ..          ...           ...
# 95   1050329046           825
# 96    858661214           305
# 97   1564981558           511
# 98   1586514356           491
# 99   6953481449           317
#
# [100 rows x 5 columns]

# %% [markdown]
# ## Pulling video information

# %%
def get_channel_videos(channel_id):
    video_ids = []
    next_page_token = None

    while True:
        request = youtube.search().list(
            part='id',
            channelId=channel_id,
            maxResults=50,
            type='video',
            pageToken=next_page_token
        )
        response = request.execute()

        for item in response['items']:
            video_ids.append(item['id']['videoId'])

        next_page_token = response.get('nextPageToken')

        if next_page_token is None:
            break

    return video_ids

channel_id = 'UC5p_l5ZeB_wGjO_yDXwiqvw'
video_ids = get_channel_videos(channel_id)
print(f"Total videos: {len(video_ids)}")
# Out:
# Total videos: 413

# %% [markdown]
# ## Pulling video details

# %%
# Extracting video details
def get_video_details(video_ids):
    stats = {
        'Views': 0,
        'Likes': 0,
        'Dislikes': 0,
        'Comments': 0  
    }
    
    for i in range(0, len(video_ids), 50):  # The API allows up to 50 video IDs per request
        request = youtube.videos().list(
            part='statistics',
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute()
        
        for item in response['items']:
            stats['Views'] += int(item['statistics'].get('viewCount', 0))
            stats['Likes'] += int(item['statistics'].get('likeCount', 0))
            stats['Dislikes'] += int(item['statistics'].get('dislikeCount', 0))
            stats['Comments'] += int(item['statistics'].get('commentCount', 0))
    
    return stats

video_stats = get_video_details(video_ids)
print(video_stats)
# Out:
# {'Views': 2217824988, 'Likes': 107301532, 'Dislikes': 0, 'Comments': 3623404}

# %% [markdown]
# ## Aggregating Data for Multiple Channels

# %% [markdown]
# As of November 2021, YouTube hides public dislike counts on all videos across its site. Hence, no need to fetch it.

# %%
import time

channel_stats = []

for index, row in channel_stats_df.iterrows(): 
    channel_name = row['Channel_name']
    channel_id = row['Channel_ID']
    print(f"Fetching videos for channel: {channel_name} (ID: {channel_id})")
    video_ids = get_channel_videos(channel_id)
    stats = get_video_details(video_ids)
    channel_stats.append({
        'Channel_id': channel_id,
        'Channel_name': channel_name,
        'Video_views': stats['Views'],
        'Total_likes': stats['Likes'],
        'Total_comments': stats['Comments'],
        'Engagement_rate': ((stats['Likes'] + stats['Comments']) / stats['Views']) * 100 if stats['Views'] > 0 else 0
    })
    
    # Sleep to manage API quotas
    time.sleep(5)

channel_data_df = pd.DataFrame(channel_stats)
print(channel_data_df)

# %%
# combined = result1_9 + result2_10 + result3_9 + result4_10 + result5_9 + result6_10 + result7_10 + result8_10 + result9_12 + result10_10 + result11_1
# len(combined)

# %%
channel_data_df
# Out:
#                   Channel_id                                    Channel_name  \
# 0   UC-FQUIVQ-bZiefzBiQAa8Fw                                     BBC Radio 1
# 1   UCKvn9VBLAiLiYL4FFJHri6g  F2Freestylers - Ultimate Soccer Skills Channel
# 2   UC5p_l5ZeB_wGjO_yDXwiqvw                                      TommyInnit
# 3   UCvwgF_0NOZe2vN4Q3g1bY-A                                     Vikkstar123
# 4   UCiMhD4jzUqG-IgPzUmmytRQ                                  Queen Official
# ..                       ...                                             ...
# 95  UCvZwcK22QTUaM18KE7mHeNw                                    Max and Katy
# 96  UCzTlXb7ivVzuFlugVCv3Kvg                                    LDShadowLady
# 97  UC-VDfQNL-S44eZscGlXI14g                                      Dumori Bay
# 98  UCOgUcv_9DaivXzsN9mcHIzQ                                          TGFbro
# 99  UCoMdktPbSTixAyNGwb-UYkQ                                        Sky News
#
#     Video_views  Total_likes  Total_comments  Engagement_rate
# 0    2009261696     29606493          816718         1.514149
# 1    2418653165     42754353         2120828         1.855379
# 2    2379613105    114763735         3872377         4.985521
# 3     499296804     13407085          477864         2.780901
# 4   10025960402     73803577         2958750         0.765636
# ..          ...          ...             ...              ...
# 95   1511569101      5319595              16         0.351926
# 96   2389072340     40507580         5601594         1.930003
# 97      1140267        38548             840         3.454279
# 98   1335319073     64102469         2044514         4.953646
# 99    538236056      5090515          873478         1.108063
#
# [100 rows x 6 columns]

# %% [markdown]
# ## 4. Merging the project data, channel statistics and video statistics data

# %%
# Renaming 'Channel_id'
channel_data_df.rename(columns={'Channel_id': 'Channel_ID'}, inplace=True)

# %%
# Merging df with channel_stats_df on 'Channel_ID'
merge_df = pd.merge(df, channel_stats_df, on='Channel_ID', suffixes=('_df', '_stats'))

# Merging the merged_df with channel_data_df on 'Channel_ID'
final_merged_df = pd.merge(merged_data, channel_data_df, on='Channel_ID', suffixes=('', '_data'))

final_merged_df

# %%
from IPython.display import display

# Sets option temporarily for this block of code
with pd.option_context('display.max_rows', 100):
    display(final_merged_df)
# Out:
#       #                                             NOMBRE SEGUIDORES     TP  \
# 0     1        NoCopyrightSounds @UC_aEa8K-EOJ3D6gOs7HcyNg      32.9M      -
# 1     2                   DanTDM @UCS5Oz6CHmeoF7vSad0qqXfw      26.3M      -
# 2     3                      KSI @UCVtFOytbRpEvzLjvqGG5gxQ        24M      -
# 3     4               Mister Max @UC_8PAD0Qmi6_gpe77S1Atgg        23M   0.1%
# 4     5                    Jelly @UC0DZmkupLYwc0yDsfocLh0A      22.9M      -
# 5     6                Miss Katy @UCcartHVtvAUzfajflyeT_Gg      22.6M      -
# 6     7                 Dua Lipa @UC-J-KZfRV8c13fOCkhXdLiQ      21.1M      -
# 7     8               Dan Rhodes @UC6D1L2vxEAg_Vi0JSxMBDgA      17.7M   0.3%
# 8     9                    Ali-A @UCYVinkwSX7szARULgYpvhLw      17.7M      -
# 9    10            Gaby and Alex @UCHwBjRoGO1V-H8QYXjSVHkQ        17M      -
# 10   11                                   Sidemen @sidemen        17M   2.8%
# 11   12           Queen Official @UCiMhD4jzUqG-IgPzUmmytRQ      16.3M      -
# 12   13               Little Mix @UCIvqWqjC4aLvp7zI8hzARrA      16.1M      -
# 13   14              JJ Olatunji @UCGmnsW623G1r-Chmo5RB4Yw      15.9M      -
# 14   15  F2Freestylers - Ultimate Soccer Skills Channel...        14M   0.2%
# 15   16                 BBC News @UC16niRr50-MSBwiO3YDb3RA      13.3M      -
# 16   17                      BBC @UCCj956IF62FbT7Gouszaj9w      12.9M      -
# 17   18          Awakening Music @UCBq5hp6DvwWam2XOXw6lYJA      12.4M      -
# 18   19          DisneyChannelUK @UCLeuoGy_hUDTBf5Hk0ynrpQ      12.3M      -
# 19   20               colinfurze @UCp68_FLety0O-n9QU6phsgw      11.9M   0.6%
# 20   21           Mrwhosetheboss @UCMiJRAwDNSNzuYeN2uWa0pA      11.8M   1.9%
# 90   91                               TheDadLab @thedadlab         5M      -
# 91   92                 Behzinga @UCHhfSXoDG6gSgpOvLH4wrRw       4.9M      -
# 92   93     BBC Learning English @UCHaHD477h-FeBbVh9Sh7syA       4.8M      -
# 93   94             Max and Katy @UCvZwcK22QTUaM18KE7mHeNw       4.8M      -
# 94   95                 Man City @UCkzCjdRMrW2vXLx8mvPVLdQ       4.8M      -
# 95   96                     Wisp @UC0h07r_UgTD0Tc-Dn5XLX3g       4.7M   1.1%
# 96   97                   WillNE @UCaFUrR3oSxOl5Y9y6tvLTEg       4.7M   2.4%
# 97   98                   Zerkaa @UChntGq8THlUokhc1tT-M2wA       4.7M   2.3%
# 98   99             Ben Phillips @UChoQQRDf-zU1h6_YjKkWvdw       4.6M      -
# 99  100               Roxxsaurus @UCBKFH7bU2ebvO68FtuGjyyw       4.5M      -
#
#                 PAÍS TEMA DE INFLUENCIA ALCANCE POTENCIAL  GUARDAR  \
# 0        Reino Unido             Música              9.9M      NaN
# 1        Reino Unido                NaN              7.9M      NaN
# 2        Reino Unido                NaN              7.2M      NaN
# 3        Reino Unido                NaN              6.9M      NaN
# 4        Reino Unido                NaN              6.9M      NaN
# 5        Reino Unido                NaN              6.8M      NaN
# 6        Reino Unido                NaN              6.3M      NaN
# 7        Reino Unido                NaN              5.3M      NaN
# 8        Reino Unido                NaN              5.3M      NaN
# 9        Reino Unido                NaN              5.1M      NaN
# 10       Reino Unido                NaN              5.1M      NaN
# 11       Reino Unido                NaN              4.9M      NaN
# 12       Reino Unido                NaN              4.8M      NaN
# 13       Reino Unido                NaN              4.8M      NaN
# 14       Reino Unido         Celebridad              4.2M      NaN
# 15       Reino Unido                NaN                4M      NaN
# 16       Reino Unido                NaN              3.9M      NaN
# 17  संयुक्त अधिराज्य             सङ्गीत              3.7M      NaN
# 18  संयुक्त अधिराज्य                NaN              3.7M      NaN
# 19  संयुक्त अधिराज्य                NaN              3.6M      NaN
# 20  संयुक्त अधिराज्य                NaN              3.5M      NaN
# 21  संयुक्त अधिराज्य                NaN              3.5M      NaN
# 22  संयुक्त अधिराज्य                NaN              3.5M      NaN
# 23  संयुक्त अधिराज्य                NaN              3.4M      NaN
# 24  संयुक्त अधिराज्य                NaN              3.4M      NaN
# 25  संयुक्त अधिराज्य                NaN              3.3M      NaN
# 26  संयुक्त अधिराज्य                NaN              3.3M      NaN
# 27  संयुक्त अधिराज्य                NaN              3.1M      NaN
# 28  संयुक्त अधिराज्य                NaN              3.1M      NaN
# 29  संयुक्त अधिराज्य                NaN                3M      NaN
# 30  संयुक्त अधिराज्य                NaN                3M      NaN
# 31  संयुक्त अधिराज्य                NaN              2.9M      NaN
# 32  संयुक्त अधिराज्य                NaN              2.8M      NaN
# 33  संयुक्त अधिराज्य                NaN              2.8M      NaN
# 34  संयुक्त अधिराज्य             यात्रा              2.8M      NaN
# 35  संयुक्त अधिराज्य                NaN              2.8M      NaN
# 36  संयुक्त अधिराज्य                NaN              2.7M      NaN
# 37  संयुक्त अधिराज्य                NaN              2.7M      NaN
# 38  संयुक्त अधिराज्य                NaN              2.7M      NaN
# 39  संयुक्त अधिराज्य                NaN              2.6M      NaN
# 40  संयुक्त अधिराज्य       भिडियो गेमिङ              2.6M      NaN
# 41  संयुक्त अधिराज्य                NaN              2.5M      NaN
# 42  संयुक्त अधिराज्य                NaN              2.5M      NaN
# 43  संयुक्त अधिराज्य                NaN              2.4M      NaN
# 44  संयुक्त अधिराज्य                NaN              2.4M      NaN
# 45  संयुक्त अधिराज्य                NaN              2.3M      NaN
# 46  संयुक्त अधिराज्य                NaN              2.3M      NaN
# 47  संयुक्त अधिराज्य                NaN              2.3M      NaN
# 48  संयुक्त अधिराज्य                NaN              2.3M      NaN
# 49  संयुक्त अधिराज्य                NaN              2.2M      NaN
# 50  संयुक्त अधिराज्य                NaN              2.2M      NaN
# 51  संयुक्त अधिराज्य                NaN              2.2M      NaN
# 52  संयुक्त अधिराज्य          समाचारहरू              2.1M      NaN
# 53  संयुक्त अधिराज्य       भिडियो गेमिङ              2.1M      NaN
# 54  संयुक्त अधिराज्य                NaN              2.1M      NaN
# 55  संयुक्त अधिराज्य                NaN              2.1M      NaN
# 56  संयुक्त अधिराज्य                NaN              2.1M      NaN
# 57  संयुक्त अधिराज्य                NaN                2M      NaN
# 58  संयुक्त अधिराज्य                NaN                2M      NaN
# 59  संयुक्त अधिराज्य                NaN                2M      NaN
# 60  संयुक्त अधिराज्य                NaN                2M      NaN
# 61  संयुक्त अधिराज्य                NaN                2M      NaN
# 62  संयुक्त अधिराज्य                NaN                2M      NaN
# 63  संयुक्त अधिराज्य                NaN                2M      NaN
# 64  संयुक्त अधिराज्य                NaN                2M      NaN
# 65  संयुक्त अधिराज्य                NaN              1.9M      NaN
# 66  संयुक्त अधिराज्य                NaN              1.9M      NaN
# 67  संयुक्त अधिराज्य                NaN              1.9M      NaN
# 68  संयुक्त अधिराज्य                NaN              1.9M      NaN
# 69  संयुक्त अधिराज्य                NaN              1.9M      NaN
# 70  संयुक्त अधिराज्य                NaN              1.9M      NaN
# 71  संयुक्त अधिराज्य                NaN              1.8M      NaN
# 72  संयुक्त अधिराज्य                NaN              1.8M      NaN
# 73  संयुक्त अधिराज्य                NaN              1.8M      NaN
# 74  संयुक्त अधिराज्य                NaN              1.8M      NaN
# 75  संयुक्त अधिराज्य                NaN              1.7M      NaN
# 76  संयुक्त अधिराज्य                NaN              1.7M      NaN
# 77  संयुक्त अधिराज्य                NaN              1.7M      NaN
# 78  संयुक्त अधिराज्य                NaN              1.7M      NaN
# 79  संयुक्त अधिराज्य                NaN              1.7M      NaN
# 80  संयुक्त अधिराज्य                NaN              1.7M      NaN
# 81  संयुक्त अधिराज्य                NaN              1.7M      NaN
# 82  संयुक्त अधिराज्य          प्रसिद्धि              1.7M      NaN
# 83  संयुक्त अधिराज्य                NaN              1.6M      NaN
# 84  संयुक्त अधिराज्य                NaN              1.6M      NaN
# 85  संयुक्त अधिराज्य                NaN              1.6M      NaN
# 86  संयुक्त अधिराज्य          प्रसिद्धि              1.6M      NaN
# 87  संयुक्त अधिराज्य                NaN              1.5M      NaN
# 88  संयुक्त अधिराज्य                NaN              1.5M      NaN
# 89  संयुक्त अधिराज्य                NaN              1.5M      NaN
# 90  संयुक्त अधिराज्य                NaN              1.5M      NaN
# 91  संयुक्त अधिराज्य                NaN              1.5M      NaN
# 92  संयुक्त अधिराज्य                NaN              1.4M      NaN
# 93  संयुक्त अधिराज्य                NaN              1.4M      NaN
# 94  संयुक्त अधिराज्य                NaN              1.4M      NaN
# 95  संयुक्त अधिराज्य                NaN              1.4M      NaN
# 96  संयुक्त अधिराज्य                NaN              1.4M      NaN
# 97  संयुक्त अधिराज्य                NaN              1.4M      NaN
# 98  संयुक्त अधिराज्य                NaN              1.4M      NaN
# 99  संयुक्त अधिराज्य                NaN              1.4M      NaN
#
#    INVITAR A LA CAMPAÑA                Channel_ID  \
# 0            Ver Perfil  UC_aEa8K-EOJ3D6gOs7HcyNg
# 1            Ver Perfil  UCS5Oz6CHmeoF7vSad0qqXfw
# 2            Ver Perfil  UCVtFOytbRpEvzLjvqGG5gxQ
# 3            Ver Perfil  UC_8PAD0Qmi6_gpe77S1Atgg
# 4            Ver Perfil  UC0DZmkupLYwc0yDsfocLh0A
# 5            Ver Perfil  UCcartHVtvAUzfajflyeT_Gg
# 6            Ver Perfil  UC-J-KZfRV8c13fOCkhXdLiQ
# 7            Ver Perfil  UC6D1L2vxEAg_Vi0JSxMBDgA
# 8            Ver Perfil  UCYVinkwSX7szARULgYpvhLw
# 9            Ver Perfil  UCHwBjRoGO1V-H8QYXjSVHkQ
# 10           Ver Perfil  UCDogdKl7t7NHzQ95aEwkdMw
# 11           Ver Perfil  UCiMhD4jzUqG-IgPzUmmytRQ
# 12           Ver Perfil  UCIvqWqjC4aLvp7zI8hzARrA
# 13           Ver Perfil  UCGmnsW623G1r-Chmo5RB4Yw
# 14           Ver Perfil  UCKvn9VBLAiLiYL4FFJHri6g
# 15           Ver Perfil  UC16niRr50-MSBwiO3YDb3RA
# 16           Ver Perfil  UCCj956IF62FbT7Gouszaj9w
# 17      प्रोफ़ाइल देखें  UCBq5hp6DvwWam2XOXw6lYJA
# 18      प्रोफ़ाइल देखें  UCLeuoGy_hUDTBf5Hk0ynrpQ
# 19      प्रोफ़ाइल देखें  UCp68_FLety0O-n9QU6phsgw
# 20      प्रोफ़ाइल देखें  UCMiJRAwDNSNzuYeN2uWa0pA
# 21      प्रोफ़ाइल देखें  UC5p_l5ZeB_wGjO_yDXwiqvw
# 22      प्रोफ़ाइल देखें  UCBwSufNse8VMBvQM_rCSvgQ
# 23      प्रोफ़ाइल देखें  UC6sSkkemzPjmrzS0Y0V_2zw
# 24      प्रोफ़ाइल देखें  UC7Gf2tZ8coTX2ckTPgn62iQ
# 25      प्रोफ़ाइल देखें  UC-0D1RlSzcvBoODCKSoLl2g
# 26      प्रोफ़ाइल देखें  UCHdMK5Ef2El8KbD3L_WgANg
# 27      प्रोफ़ाइल देखें  UC4pEp0mo54WhEBCTYvjVDJA
# 28      प्रोफ़ाइल देखें  UCwTRjvjVge51X-ILJ4i22ew
# 29      प्रोफ़ाइल देखें  UCelk6aHijZq-GJBBB9YpReA
# 30      प्रोफ़ाइल देखें  UCEwIUtFBhaI2L2PuKv0KL2g
# 31      प्रोफ़ाइल देखें  UC1ieoHqKW-yYgDhLHIcx28w
# 32      प्रोफ़ाइल देखें  UCfIXdjDQH9Fau7y99_Orpjw
# 33      प्रोफ़ाइल देखें  UCoGForHQAmk0_9rI9CABeYw
# 34      प्रोफ़ाइल देखें  UChUHOEe7zgYmrv7a_LlpNng
# 35      प्रोफ़ाइल देखें  UCCNaMMlI3cOc7yFg52riTqg
# 36      प्रोफ़ाइल देखें  UCEY1ejsweY4DgMwOVJeEaBA
# 37      प्रोफ़ाइल देखें  UCz4tgANd4yy8Oe0iXCdSWfA
# 38      प्रोफ़ाइल देखें  UCS7H8U-n5mINVJjJsaRtGHg
# 39      प्रोफ़ाइल देखें  UC977n5nXRn8MDuGQjwxkOLw
# 40      प्रोफ़ाइल देखें  UChFur_NwVSbUozOcF_F2kMg
# 41      प्रोफ़ाइल देखें  UCjOl2AUblVmg2rA_cRgZkFg
# 42      प्रोफ़ाइल देखें  UC1QqdFv5e9QSEi0eYdfwuqw
# 43      प्रोफ़ाइल देखें  UC-FQUIVQ-bZiefzBiQAa8Fw
# 44      प्रोफ़ाइल देखें  UC9LQwHZoucFT94I2h6JOcjw
# 45      प्रोफ़ाइल देखें  UCR9Gcq0CMm6YgTzsDxAxjOQ
# 46      प्रोफ़ाइल देखें  UCDBCCMlFD-hArPbWv38FINA
# 47      प्रोफ़ाइल देखें  UCvwgF_0NOZe2vN4Q3g1bY-A
# 48      प्रोफ़ाइल देखें  UCHFA6Nt11kE_8OWIya0SQDQ
# 49      प्रोफ़ाइल देखें  UCUhFaUpnq31m6TNX2VKVSVA
# 50      प्रोफ़ाइल देखें  UC5Y1pPVNm-odhiubuRO1D6A
# 51      प्रोफ़ाइल देखें  UCOYWgypDktXdb-HfZnSMK6A
# 52      प्रोफ़ाइल देखें  UCH-_hzb2ILSCo9ftVSnrCIQ
# 53      प्रोफ़ाइल देखें  UCzTlXb7ivVzuFlugVCv3Kvg
# 54      प्रोफ़ाइल देखें  UCc4K7bAqpdBP8jh1j9XZAww
# 55      प्रोफ़ाइल देखें  UCFHtCB_FWXQ8GpjgfYcD8-g
# 56      प्रोफ़ाइल देखें  UCrSgaO6xOY8YV1EoCbD51HA
# 57      प्रोफ़ाइल देखें  UCh5mLn90vUaB1PbRRx_AiaA
# 58      प्रोफ़ाइल देखें  UCmst562fALOY2cKb4IFgqEg
# 59      प्रोफ़ाइल देखें  UCV5Gw7GGOMxe6SSF6llp_3Q
# 60      प्रोफ़ाइल देखें  UCrSx8rek9EuC3YGHvG8aalw
# 61      प्रोफ़ाइल देखें  UCcmpeVbSSQlZRvHfdC-CRwg
# 62      प्रोफ़ाइल देखें  UC_wITz-Ze4JFc3WLQA1n3Hw
# 63      प्रोफ़ाइल देखें  UCHiceVclOIFCgAcveITRLLw
# 64      प्रोफ़ाइल देखें  UCSY5V7BJSrxNvvBF0Drslow
# 65      प्रोफ़ाइल देखें  UCQdsJ95w9jh-yB0BA6EDGWA
# 66      प्रोफ़ाइल देखें  UCfLFTP1uTuIizynWsZq2nkQ
# 67      प्रोफ़ाइल देखें  UCOgUcv_9DaivXzsN9mcHIzQ
# 68      प्रोफ़ाइल देखें  UC1n_PfsVqxllCcnMPlxBIjw
# 69      प्रोफ़ाइल देखें  UCswH8ovgUp5Bdg-0_JTYFNw
# 70      प्रोफ़ाइल देखें  UC6yW44UGJJBvYTlfC7CRg2Q
# 71      प्रोफ़ाइल देखें  UCM88mtSE0zRTn5ae4EbYcuw
# 72      प्रोफ़ाइल देखें  UCZSlfzadjnw7G419c_OJ9eg
# 73      प्रोफ़ाइल देखें  UCdcUmdOxMrhRjKMw-BX19AA
# 74      प्रोफ़ाइल देखें  UC7_yh9PEDpaqp34QtGO-_Yw
# 75      प्रोफ़ाइल देखें  UCZzwjZPc6R_PbnDgFVMwlvQ
# 76      प्रोफ़ाइल देखें  UCH6vXjt-BA7QHl0KnfL-7RQ
# 77      प्रोफ़ाइल देखें  UC2C_jShtL725hvbm1arSV9w
# 78      प्रोफ़ाइल देखें  UCpSgg_ECBj25s9moCDfSTsA
# 79      प्रोफ़ाइल देखें  UCQ-YJstgVdAiCT52TiBWDbg
# 80      प्रोफ़ाइल देखें  UC-VDfQNL-S44eZscGlXI14g
# 81      प्रोफ़ाइल देखें  UCakgsb0w7QB0VHdnCc-OVEA
# 82      प्रोफ़ाइल देखें  UCu4XcDBdnZkV6-5z2f16M0g
# 83      प्रोफ़ाइल देखें  UCO66lK14MYiXlu0A6pQ4ouA
# 84      प्रोफ़ाइल देखें  UCqTwKvjbTENZDGbz2si47ag
# 85      प्रोफ़ाइल देखें  UCLk9wddjT0F-HILLRFXodtg
# 86      प्रोफ़ाइल देखें  UCbmWOFTbZoDLWqG1rvFnJ0g
# 87      प्रोफ़ाइल देखें  UCoMdktPbSTixAyNGwb-UYkQ
# 88      प्रोफ़ाइल देखें  UCvxfEIG3PHpgM0TMJJ_SH-w
# 89      प्रोफ़ाइल देखें  UCRlICXvO4XR4HMeEB9JjDlA
# 90      प्रोफ़ाइल देखें  UCc_-hy0u9-oKlNdMKHBudcQ
# 91      प्रोफ़ाइल देखें  UCHhfSXoDG6gSgpOvLH4wrRw
# 92      प्रोफ़ाइल देखें  UCHaHD477h-FeBbVh9Sh7syA
# 93      प्रोफ़ाइल देखें  UCvZwcK22QTUaM18KE7mHeNw
# 94      प्रोफ़ाइल देखें  UCkzCjdRMrW2vXLx8mvPVLdQ
# 95      प्रोफ़ाइल देखें  UC0h07r_UgTD0Tc-Dn5XLX3g
# 96      प्रोफ़ाइल देखें  UCaFUrR3oSxOl5Y9y6tvLTEg
# 97      प्रोफ़ाइल देखें  UChntGq8THlUokhc1tT-M2wA
# 98      प्रोफ़ाइल देखें  UChoQQRDf-zU1h6_YjKkWvdw
# 99      प्रोफ़ाइल देखें  UCBKFH7bU2ebvO68FtuGjyyw
#
#                                    Channel_name_df  \
# 0                                NoCopyrightSounds
# 1                                           DanTDM
# 2                                              KSI
# 3                                       Mister Max
# 4                                            Jelly
# 5                                        Miss Katy
# 6                                         Dua Lipa
# 7                                       Dan Rhodes
# 8                                            Ali-A
# 34     19876807              29         0.361555
# 35     56761851          194857         2.303179
# 36     19494102           24978         0.746481
# 37     17781744          760920         3.790519
# 38      7104692              34         0.461639
# 39       137577              10         0.508900
# 40     56247673         3475641         4.109278
# 41     19531120         1055965         0.977228
# 42     24845080               0         0.357564
# 43     29606493          816718         1.514149
# 44     16374732          453871         2.347287
# 45     62137412         5399099         3.457748
# 46     46120641         3123910         3.260708
# 47     13407085          477864         2.780901
# 48      7502796               0         0.291814
# 49     35430830         1928682         2.667838
# 50    166481188         1204033         4.340956
# 51     40454389         2789921         2.077373
# 52      7931188          689195         2.320900
# 53     40507580         5601594         1.930003
# 54      4010440          233556         1.976020
# 55     24090078          697472         0.560930
# 56     21925490         2113246         1.922895
# 57     96291504         1849006         3.390625
# 58      9033799               0         0.356042
# 59      1174824           39891         3.888586
# 60      8431225               0         0.361342
# 61      1647234           96572         1.200492
# 62     15572970               0         0.324867
# 63     18444540               0         0.447078
# 64        30170            2455         0.820714
# 65    201711145          682967         4.095359
# 66      6918931          550964         0.954404
# 67     64102469         2044514         4.953646
# 68     35661125         1619242         4.669225
# 69     19330033         2731321         6.629169
# 70     21099171          414977         2.970393
# 71      5435648               0         0.298885
# 72    259656446         1076051         6.813072
# 73     35128102          901950         5.726156
# 74     16902407          100100         1.055403
# 75     29476810          649877         1.219583
# 76     14382183          425666         0.977542
# 77     28097162         1571323         2.779019
# 78      6493578          226550         1.470762
# 79     31303924         1145626         2.215480
# 80        38548             840         3.454279
# 81       166691            3939         1.537034
# 82      5016436          850088         1.020483
# 83      4234384               5         0.299954
# 84     43559583         1044251         0.971856
# 85     25651090         1575007         2.621421
# 86      3626481               0         0.329329
# 87      5090515          873478         1.108063
# 88     41619690         1319908         2.863768
# 89     23620875         2088113         3.300395
# 90      8025855            5289         0.283576
# 91     12521150          582097         4.251231
# 92      2348696           43812         3.050299
# 93      5319595              16         0.351926
# 94      8860919          224827         1.919587
# 95     29622855         1056463         2.973664
# 96     38033559         1357639         4.592635
# 97     16856388          376554         5.361586
# 98     19019161         1509130         3.118248
# 99      9916635          394087         3.303757

# %%
final_merged_df.drop(columns=['Channel_name_df', 'Channel_name'], inplace=True)
final_merged_df.rename(columns={'Channel_name_stats': 'Channel_name'}, inplace=True)
final_merged_df
# Out:
#       #                                             NOMBRE SEGUIDORES     TP  \
# 0     1        NoCopyrightSounds @UC_aEa8K-EOJ3D6gOs7HcyNg      32.9M      -
# 1     2                   DanTDM @UCS5Oz6CHmeoF7vSad0qqXfw      26.3M      -
# 2     3                      KSI @UCVtFOytbRpEvzLjvqGG5gxQ        24M      -
# 3     4               Mister Max @UC_8PAD0Qmi6_gpe77S1Atgg        23M   0.1%
# 4     5                    Jelly @UC0DZmkupLYwc0yDsfocLh0A      22.9M      -
# 5     6                Miss Katy @UCcartHVtvAUzfajflyeT_Gg      22.6M      -
# 6     7                 Dua Lipa @UC-J-KZfRV8c13fOCkhXdLiQ      21.1M      -
# 7     8               Dan Rhodes @UC6D1L2vxEAg_Vi0JSxMBDgA      17.7M   0.3%
# 76   77              Simon's Cat @UCH6vXjt-BA7QHl0KnfL-7RQ       5.8M   0.3%
# 77   78                 CGP Grey @UC2C_jShtL725hvbm1arSV9w       5.8M      -
# 78   79             Jamie Oliver @UCpSgg_ECBj25s9moCDfSTsA       5.8M      -
# 79   80                            ChrisMD @sirhcchris2010       5.6M   2.2%
# 80   81               Dumori Bay @UC-VDfQNL-S44eZscGlXI14g       5.6M      -
# 81   82             Space Videos @UCakgsb0w7QB0VHdnCc-OVEA       5.5M      -
# 82   83             Real Stories @UCu4XcDBdnZkV6-5z2f16M0g       5.5M      -
# 83   84               More Emily @UCO66lK14MYiXlu0A6pQ4ouA       5.4M      -
# 84   85                GRM Daily @UCqTwKvjbTENZDGbz2si47ag       5.3M      -
# 85   86               Joe Weller @UCLk9wddjT0F-HILLRFXodtg       5.3M   1.9%
# 86   87           WildBrain Kids @UCbmWOFTbZoDLWqG1rvFnJ0g       5.2M      -
# 87   88                 Sky News @UCoMdktPbSTixAyNGwb-UYkQ       5.2M      -
# 88   89                   Jarvis @UCvxfEIG3PHpgM0TMJJ_SH-w         5M   0.8%
# 89   90                Thoughty2 @UCRlICXvO4XR4HMeEB9JjDlA         5M      -
# 90   91                               TheDadLab @thedadlab         5M      -
# 91   92                 Behzinga @UCHhfSXoDG6gSgpOvLH4wrRw       4.9M      -
# 92   93     BBC Learning English @UCHaHD477h-FeBbVh9Sh7syA       4.8M      -
# 93   94             Max and Katy @UCvZwcK22QTUaM18KE7mHeNw       4.8M      -
# 94   95                 Man City @UCkzCjdRMrW2vXLx8mvPVLdQ       4.8M      -
# 95   96                     Wisp @UC0h07r_UgTD0Tc-Dn5XLX3g       4.7M   1.1%
# 96   97                   WillNE @UCaFUrR3oSxOl5Y9y6tvLTEg       4.7M   2.4%
# 97   98                   Zerkaa @UChntGq8THlUokhc1tT-M2wA       4.7M   2.3%
# 98   99             Ben Phillips @UChoQQRDf-zU1h6_YjKkWvdw       4.6M      -
# 99  100               Roxxsaurus @UCBKFH7bU2ebvO68FtuGjyyw       4.5M      -
#
#                 PAÍS TEMA DE INFLUENCIA ALCANCE POTENCIAL  GUARDAR  \
# 0        Reino Unido             Música              9.9M      NaN
# 1        Reino Unido                NaN              7.9M      NaN
# 2        Reino Unido                NaN              7.2M      NaN
# 3        Reino Unido                NaN              6.9M      NaN
# 4        Reino Unido                NaN              6.9M      NaN
# 5        Reino Unido                NaN              6.8M      NaN
# 6        Reino Unido                NaN              6.3M      NaN
# 7        Reino Unido                NaN              5.3M      NaN
# 8        Reino Unido                NaN              5.3M      NaN
# 9        Reino Unido                NaN              5.1M      NaN
# 10       Reino Unido                NaN              5.1M      NaN
# 11       Reino Unido                NaN              4.9M      NaN
# 12       Reino Unido                NaN              4.8M      NaN
# 13       Reino Unido                NaN              4.8M      NaN
# 14       Reino Unido         Celebridad              4.2M      NaN
# 15       Reino Unido                NaN                4M      NaN
# 16       Reino Unido                NaN              3.9M      NaN
# 17  संयुक्त अधिराज्य             सङ्गीत              3.7M      NaN
# 18  संयुक्त अधिराज्य                NaN              3.7M      NaN
# 19  संयुक्त अधिराज्य                NaN              3.6M      NaN
# 20  संयुक्त अधिराज्य                NaN              3.5M      NaN
# 21  संयुक्त अधिराज्य                NaN              3.5M      NaN
# 22  संयुक्त अधिराज्य                NaN              3.5M      NaN
# 23  संयुक्त अधिराज्य                NaN              3.4M      NaN
# 24  संयुक्त अधिराज्य                NaN              3.4M      NaN
# 25  संयुक्त अधिराज्य                NaN              3.3M      NaN
# 26  संयुक्त अधिराज्य                NaN              3.3M      NaN
# 27  संयुक्त अधिराज्य                NaN              3.1M      NaN
# 28  संयुक्त अधिराज्य                NaN              3.1M      NaN
# 29  संयुक्त अधिराज्य                NaN                3M      NaN
# 30  संयुक्त अधिराज्य                NaN                3M      NaN
# 31  संयुक्त अधिराज्य                NaN              2.9M      NaN
# 32  संयुक्त अधिराज्य                NaN              2.8M      NaN
# 33  संयुक्त अधिराज्य                NaN              2.8M      NaN
# 34  संयुक्त अधिराज्य             यात्रा              2.8M      NaN
# 35  संयुक्त अधिराज्य                NaN              2.8M      NaN
# 36  संयुक्त अधिराज्य                NaN              2.7M      NaN
# 37  संयुक्त अधिराज्य                NaN              2.7M      NaN
# 38  संयुक्त अधिराज्य                NaN              2.7M      NaN
# 39  संयुक्त अधिराज्य                NaN              2.6M      NaN
# 40  संयुक्त अधिराज्य       भिडियो गेमिङ              2.6M      NaN
# 41  संयुक्त अधिराज्य                NaN              2.5M      NaN
# 42  संयुक्त अधिराज्य                NaN              2.5M      NaN
# 43  संयुक्त अधिराज्य                NaN              2.4M      NaN
# 44  संयुक्त अधिराज्य                NaN              2.4M      NaN
# 45  संयुक्त अधिराज्य                NaN              2.3M      NaN
# 46  संयुक्त अधिराज्य                NaN              2.3M      NaN
# 47  संयुक्त अधिराज्य                NaN              2.3M      NaN
# 48  संयुक्त अधिराज्य                NaN              2.3M      NaN
# 49  संयुक्त अधिराज्य                NaN              2.2M      NaN
# 50  संयुक्त अधिराज्य                NaN              2.2M      NaN
# 51  संयुक्त अधिराज्य                NaN              2.2M      NaN
# 52  संयुक्त अधिराज्य          समाचारहरू              2.1M      NaN
# 53  संयुक्त अधिराज्य       भिडियो गेमिङ              2.1M      NaN
# 54  संयुक्त अधिराज्य                NaN              2.1M      NaN
# 55  संयुक्त अधिराज्य                NaN              2.1M      NaN
# 56  संयुक्त अधिराज्य                NaN              2.1M      NaN
# 57  संयुक्त अधिराज्य                NaN                2M      NaN
# 58  संयुक्त अधिराज्य                NaN                2M      NaN
# 59  संयुक्त अधिराज्य                NaN                2M      NaN
# 60  संयुक्त अधिराज्य                NaN                2M      NaN
# 61  संयुक्त अधिराज्य                NaN                2M      NaN
# 62  संयुक्त अधिराज्य                NaN                2M      NaN
# 63  संयुक्त अधिराज्य                NaN                2M      NaN
# 64  संयुक्त अधिराज्य                NaN                2M      NaN
# 65  संयुक्त अधिराज्य                NaN              1.9M      NaN
# 66  संयुक्त अधिराज्य                NaN              1.9M      NaN
# 67  संयुक्त अधिराज्य                NaN              1.9M      NaN
# 68  संयुक्त अधिराज्य                NaN              1.9M      NaN
# 69  संयुक्त अधिराज्य                NaN              1.9M      NaN
# 70  संयुक्त अधिराज्य                NaN              1.9M      NaN
# 71  संयुक्त अधिराज्य                NaN              1.8M      NaN
# 72  संयुक्त अधिराज्य                NaN              1.8M      NaN
# 73  संयुक्त अधिराज्य                NaN              1.8M      NaN
# 74  संयुक्त अधिराज्य                NaN              1.8M      NaN
# 75  संयुक्त अधिराज्य                NaN              1.7M      NaN
# 76  संयुक्त अधिराज्य                NaN              1.7M      NaN
# 77  संयुक्त अधिराज्य                NaN              1.7M      NaN
# 78  संयुक्त अधिराज्य                NaN              1.7M      NaN
# 79  संयुक्त अधिराज्य                NaN              1.7M      NaN
# 80  संयुक्त अधिराज्य                NaN              1.7M      NaN
# 81  संयुक्त अधिराज्य                NaN              1.7M      NaN
# 82  संयुक्त अधिराज्य          प्रसिद्धि              1.7M      NaN
# 83  संयुक्त अधिराज्य                NaN              1.6M      NaN
# 84  संयुक्त अधिराज्य                NaN              1.6M      NaN
# 85  संयुक्त अधिराज्य                NaN              1.6M      NaN
# 86  संयुक्त अधिराज्य          प्रसिद्धि              1.6M      NaN
# 87  संयुक्त अधिराज्य                NaN              1.5M      NaN
# 88  संयुक्त अधिराज्य                NaN              1.5M      NaN
# 89  संयुक्त अधिराज्य                NaN              1.5M      NaN
# 90  संयुक्त अधिराज्य                NaN              1.5M      NaN
# 91  संयुक्त अधिराज्य                NaN              1.5M      NaN
# 92  संयुक्त अधिराज्य                NaN              1.4M      NaN
# 93  संयुक्त अधिराज्य                NaN              1.4M      NaN
# 94  संयुक्त अधिराज्य                NaN              1.4M      NaN
# 95  संयुक्त अधिराज्य                NaN              1.4M      NaN
# 96  संयुक्त अधिराज्य                NaN              1.4M      NaN
# 97  संयुक्त अधिराज्य                NaN              1.4M      NaN
# 98  संयुक्त अधिराज्य                NaN              1.4M      NaN
# 99  संयुक्त अधिराज्य                NaN              1.4M      NaN
#
#    INVITAR A LA CAMPAÑA                Channel_ID  \
# 0            Ver Perfil  UC_aEa8K-EOJ3D6gOs7HcyNg
# 1            Ver Perfil  UCS5Oz6CHmeoF7vSad0qqXfw
# 2            Ver Perfil  UCVtFOytbRpEvzLjvqGG5gxQ
# 3            Ver Perfil  UC_8PAD0Qmi6_gpe77S1Atgg
# 4            Ver Perfil  UC0DZmkupLYwc0yDsfocLh0A
# 5            Ver Perfil  UCcartHVtvAUzfajflyeT_Gg
# 6            Ver Perfil  UC-J-KZfRV8c13fOCkhXdLiQ
# 7            Ver Perfil  UC6D1L2vxEAg_Vi0JSxMBDgA
# 8            Ver Perfil  UCYVinkwSX7szARULgYpvhLw
# 9            Ver Perfil  UCHwBjRoGO1V-H8QYXjSVHkQ
# 10           Ver Perfil  UCDogdKl7t7NHzQ95aEwkdMw
# 11           Ver Perfil  UCiMhD4jzUqG-IgPzUmmytRQ
# 12           Ver Perfil  UCIvqWqjC4aLvp7zI8hzARrA
# 13           Ver Perfil  UCGmnsW623G1r-Chmo5RB4Yw
# 14           Ver Perfil  UCKvn9VBLAiLiYL4FFJHri6g
# 15           Ver Perfil  UC16niRr50-MSBwiO3YDb3RA
# 16           Ver Perfil  UCCj956IF62FbT7Gouszaj9w
# 17      प्रोफ़ाइल देखें  UCBq5hp6DvwWam2XOXw6lYJA
# 18      प्रोफ़ाइल देखें  UCLeuoGy_hUDTBf5Hk0ynrpQ
# 19      प्रोफ़ाइल देखें  UCp68_FLety0O-n9QU6phsgw
# 20      प्रोफ़ाइल देखें  UCMiJRAwDNSNzuYeN2uWa0pA
# 21      प्रोफ़ाइल देखें  UC5p_l5ZeB_wGjO_yDXwiqvw
# 22      प्रोफ़ाइल देखें  UCBwSufNse8VMBvQM_rCSvgQ
# 23      प्रोफ़ाइल देखें  UC6sSkkemzPjmrzS0Y0V_2zw
# 24      प्रोफ़ाइल देखें  UC7Gf2tZ8coTX2ckTPgn62iQ
# 25      प्रोफ़ाइल देखें  UC-0D1RlSzcvBoODCKSoLl2g
# 26      प्रोफ़ाइल देखें  UCHdMK5Ef2El8KbD3L_WgANg
# 27      प्रोफ़ाइल देखें  UC4pEp0mo54WhEBCTYvjVDJA
# 28      प्रोफ़ाइल देखें  UCwTRjvjVge51X-ILJ4i22ew
# 29      प्रोफ़ाइल देखें  UCelk6aHijZq-GJBBB9YpReA
# 30      प्रोफ़ाइल देखें  UCEwIUtFBhaI2L2PuKv0KL2g
# 31      प्रोफ़ाइल देखें  UC1ieoHqKW-yYgDhLHIcx28w
# 32      प्रोफ़ाइल देखें  UCfIXdjDQH9Fau7y99_Orpjw
# 33      प्रोफ़ाइल देखें  UCoGForHQAmk0_9rI9CABeYw
# 34      प्रोफ़ाइल देखें  UChUHOEe7zgYmrv7a_LlpNng
# 35      प्रोफ़ाइल देखें  UCCNaMMlI3cOc7yFg52riTqg
# 36      प्रोफ़ाइल देखें  UCEY1ejsweY4DgMwOVJeEaBA
# 37      प्रोफ़ाइल देखें  UCz4tgANd4yy8Oe0iXCdSWfA
# 38      प्रोफ़ाइल देखें  UCS7H8U-n5mINVJjJsaRtGHg
# 39      प्रोफ़ाइल देखें  UC977n5nXRn8MDuGQjwxkOLw
# 40      प्रोफ़ाइल देखें  UChFur_NwVSbUozOcF_F2kMg
# 41      प्रोफ़ाइल देखें  UCjOl2AUblVmg2rA_cRgZkFg
# 42      प्रोफ़ाइल देखें  UC1QqdFv5e9QSEi0eYdfwuqw
# 43      प्रोफ़ाइल देखें  UC-FQUIVQ-bZiefzBiQAa8Fw
# 44      प्रोफ़ाइल देखें  UC9LQwHZoucFT94I2h6JOcjw
# 45      प्रोफ़ाइल देखें  UCR9Gcq0CMm6YgTzsDxAxjOQ
# 46      प्रोफ़ाइल देखें  UCDBCCMlFD-hArPbWv38FINA
# 47      प्रोफ़ाइल देखें  UCvwgF_0NOZe2vN4Q3g1bY-A
# 48      प्रोफ़ाइल देखें  UCHFA6Nt11kE_8OWIya0SQDQ
# 49      प्रोफ़ाइल देखें  UCUhFaUpnq31m6TNX2VKVSVA
# 50      प्रोफ़ाइल देखें  UC5Y1pPVNm-odhiubuRO1D6A
# 51      प्रोफ़ाइल देखें  UCOYWgypDktXdb-HfZnSMK6A
# 52      प्रोफ़ाइल देखें  UCH-_hzb2ILSCo9ftVSnrCIQ
# 53      प्रोफ़ाइल देखें  UCzTlXb7ivVzuFlugVCv3Kvg
# 54      प्रोफ़ाइल देखें  UCc4K7bAqpdBP8jh1j9XZAww
# 55      प्रोफ़ाइल देखें  UCFHtCB_FWXQ8GpjgfYcD8-g
# 56      प्रोफ़ाइल देखें  UCrSgaO6xOY8YV1EoCbD51HA
# 57      प्रोफ़ाइल देखें  UCh5mLn90vUaB1PbRRx_AiaA
# 58      प्रोफ़ाइल देखें  UCmst562fALOY2cKb4IFgqEg
# 59      प्रोफ़ाइल देखें  UCV5Gw7GGOMxe6SSF6llp_3Q
# 60      प्रोफ़ाइल देखें  UCrSx8rek9EuC3YGHvG8aalw
# 61      प्रोफ़ाइल देखें  UCcmpeVbSSQlZRvHfdC-CRwg
# 62      प्रोफ़ाइल देखें  UC_wITz-Ze4JFc3WLQA1n3Hw
# 63      प्रोफ़ाइल देखें  UCHiceVclOIFCgAcveITRLLw
# 64      प्रोफ़ाइल देखें  UCSY5V7BJSrxNvvBF0Drslow
# 65      प्रोफ़ाइल देखें  UCQdsJ95w9jh-yB0BA6EDGWA
# 66      प्रोफ़ाइल देखें  UCfLFTP1uTuIizynWsZq2nkQ
# 67      प्रोफ़ाइल देखें  UCOgUcv_9DaivXzsN9mcHIzQ
# 68      प्रोफ़ाइल देखें  UC1n_PfsVqxllCcnMPlxBIjw
# 69      प्रोफ़ाइल देखें  UCswH8ovgUp5Bdg-0_JTYFNw
# 70      प्रोफ़ाइल देखें  UC6yW44UGJJBvYTlfC7CRg2Q
# 71      प्रोफ़ाइल देखें  UCM88mtSE0zRTn5ae4EbYcuw
# 72      प्रोफ़ाइल देखें  UCZSlfzadjnw7G419c_OJ9eg
# 73      प्रोफ़ाइल देखें  UCdcUmdOxMrhRjKMw-BX19AA
# 74      प्रोफ़ाइल देखें  UC7_yh9PEDpaqp34QtGO-_Yw
# 75      प्रोफ़ाइल देखें  UCZzwjZPc6R_PbnDgFVMwlvQ
# 76      प्रोफ़ाइल देखें  UCH6vXjt-BA7QHl0KnfL-7RQ
# 77      प्रोफ़ाइल देखें  UC2C_jShtL725hvbm1arSV9w
# 78      प्रोफ़ाइल देखें  UCpSgg_ECBj25s9moCDfSTsA
# 79      प्रोफ़ाइल देखें  UCQ-YJstgVdAiCT52TiBWDbg
# 80      प्रोफ़ाइल देखें  UC-VDfQNL-S44eZscGlXI14g
# 81      प्रोफ़ाइल देखें  UCakgsb0w7QB0VHdnCc-OVEA
# 82      प्रोफ़ाइल देखें  UCu4XcDBdnZkV6-5z2f16M0g
# 83      प्रोफ़ाइल देखें  UCO66lK14MYiXlu0A6pQ4ouA
# 84      प्रोफ़ाइल देखें  UCqTwKvjbTENZDGbz2si47ag
# 85      प्रोफ़ाइल देखें  UCLk9wddjT0F-HILLRFXodtg
# 86      प्रोफ़ाइल देखें  UCbmWOFTbZoDLWqG1rvFnJ0g
# 87      प्रोफ़ाइल देखें  UCoMdktPbSTixAyNGwb-UYkQ
# 88      प्रोफ़ाइल देखें  UCvxfEIG3PHpgM0TMJJ_SH-w
# 89      प्रोफ़ाइल देखें  UCRlICXvO4XR4HMeEB9JjDlA
# 80           225      1140267        38548             840         3.454279
# 81           139     11101248       166691            3939         1.537034
# 82          1103    574876982      5016436          850088         1.020483
# 83           634   1411678090      4234384               5         0.299954
# 84         14878   4589553443     43559583         1044251         0.971856
# 85           321   1038600673     25651090         1575007         2.621421
# 86          4999   1101171278      3626481               0         0.329329
# 87         48257    538236056      5090515          873478         1.108063
# 88           718   1499409011     41619690         1319908         2.863768
# 89           825    778966961     23620875         2088113         3.300395
# 90           832   2832095997      8025855            5289         0.283576
# 91           872    308222412     12521150          582097         4.251231
# 92          3629     78435203      2348696           43812         3.050299
# 93           508   1511569101      5319595              16         0.351926
# 94          8419    473317741      8860919          224827         1.919587
# 95           524   1031701063     29622855         1056463         2.973664
# 96           305    857703590     38033559         1357639         4.592635
# 97          2021    321415000     16856388          376554         5.361586
# 98           860    658327787     19019161         1509130         3.118248
# 99           950    312090851      9916635          394087         3.303757

# %%
# Creating mapping dictionary for video categorisation
category_mapping = {
    'NoCopyrightSounds': 'Music/Artists',
    'Dua Lipa': 'Music/Artists',
    'Queen Official': 'Music/Artists',
    'Little Mix': 'Music/Artists',
    'Jessie J': 'Music/Artists',
    'Gorillaz': 'Music/Artists',
    'The Beatles': 'Music/Artists',
    'Passenger': 'Music/Artists',
    'Mark Ronson': 'Music/Artists',
    'UKF Dubstep': 'Music/Artists',
    'Capital FM': 'Music/Artists',
    'James Arthur': 'Music/Artists',
    'GRM Daily': 'Music/Artists',
    'DanTDM': 'Gaming/Gamers',
    'KSI': 'Gaming/Gamers',
    'Ali-A': 'Gaming/Gamers',
    'Sidemen': 'Gaming/Gamers',
    'JJ Olatunji': 'Gaming/Gamers',
    'Syndicate': 'Gaming/Gamers',
    'Mumbo Jumbo': 'Gaming/Gamers',
    'Grian': 'Gaming/Gamers',
    'Daz Games': 'Gaming/Gamers',
    'Vikkstar123': 'Gaming/Gamers',
    'The Yogscast': 'Gaming/Gamers',
    'LDShadowLady': 'Gaming/Gamers',
    'TommyInnit': 'Gaming/Gamers',
    'Morgz': 'Gaming/Gamers',
    'Wilbur Soot': 'Gaming/Gamers',
    'Behzinga': 'Gaming/Gamers',
    'Wisp': 'Gaming/Gamers',
    'WillNE': 'Gaming/Gamers',
    'Zerkaa': 'Gaming/Gamers',
    'Mister Max': 'Comedy/Vloggers',
    'Jelly': 'Comedy/Vloggers',
    'Miss Katy': 'Comedy/Vloggers',
    'Dan Rhodes': 'Comedy/Vloggers',
    'Gaby and Alex': 'Comedy/Vloggers',
    'MoreSidemen': 'Comedy/Vloggers',
    'MessYourself': 'Comedy/Vloggers',
    'Russell Brand': 'Comedy/Vloggers',
    'Niko Omilana': 'Comedy/Vloggers',
    'Joe Weller': 'Comedy/Vloggers',
    'Jeremy Lynch': 'Comedy/Vloggers',
    'TomSka': 'Comedy/Vloggers',
    'Rhia Official': 'Comedy/Vloggers',
    'DisneyChannelUK': 'Kids/Family Entertainment',
    'Disney Kids': 'Kids/Family Entertainment',
    'Emily Tube': 'Kids/Family Entertainment',
    'Slogo': 'Kids/Family Entertainment',
    'Sing King': 'Kids/Family Entertainment',
    'Woody & Kleiny': 'Kids/Family Entertainment',
    'Jungle Beat': 'Kids/Family Entertainment',
    'Shaun the Sheep Official': 'Kids/Family Entertainment',
    'Cartoons for Kids': 'Kids/Family Entertainment',
    'Moonbug Kids - Kids Learning Videos': 'Kids/Family Entertainment',
    'PlayToys': 'Kids/Family Entertainment',
    'ARPO The Robot': 'Kids/Family Entertainment',
    'RubyandBonnie': 'Kids/Family Entertainment',
    'Nickelodeon UK': 'Kids/Family Entertainment',
    'Pingu - Official Channel': 'Kids/Family Entertainment',
    'Tiana2': 'Kids/Family Entertainment',
    'WildBrain Kids': 'Kids/Family Entertainment',
    'Max and Katy': 'Kids/Family Entertainment',
    'TheDadLab': 'Kids/Family Entertainment',
    'English with Lucy': 'Educational',
    'BBC Learning English': 'Educational',
    'BBC News': 'News/Talk Shows',
    'BBC News عربي': 'News/Talk Shows',
    '24 News HD': 'News/Talk Shows',
    'Sky News': 'News/Talk Shows',
    'BBC Radio 1': 'News/Talk Shows',
    'CGP Grey': 'News/Talk Shows',
    'Thoughty2': 'News/Talk Shows',
    'Real Stories': 'News/Talk Shows',
    'Boomerang UK': 'News/Talk Shows',
    'F2Freestylers - Ultimate Soccer Skills Channel': 'Sports',
    'Liverpool FC': 'Sports',
    'Manchester United': 'Sports',
    'Man City': 'Sports',
    'colinfurze': 'Automotive',
    'Mrwhosetheboss': 'Technology',
    'Mrwhosetheboss Shorts': 'Technology',
    'carwow': 'Automotive',
    'Top Gear': 'Automotive',
    'Jamie Oliver': 'Food/Cooking',
    'Classic Mr Bean': 'Classic TV/Film',
    'Space Videos': 'Science/Space',
    'The X Factor UK': 'Entertainment',
    "Simon's Cat": 'Entertainment',
    'Ben Phillips': 'Entertainment',
    'Dumori Bay': 'Entertainment',
    'TGFbro': 'Comedy/Vloggers',
    'Jarvis': 'Comedy/Vloggers',
    'Roxxsaurus': 'Miscellaneous',
    'BBC': 'News/Talk Shows',
    'Awakening Music': 'Music/Artists',
    'Tiana': 'Comedy/Vloggers',
    'Julius Dein': 'Entertainment',
    'ChrisMD': 'Sports',
    'More Emily': 'Kids/Family Entertainment'
}

# Creating the 'Video_category' column by mapping the 'Channel_name' column
final_merged_df['Channel_category'] = final_merged_df['Channel_name'].map(category_mapping)

# %%
# Creating mapping dictionary for target audience demographic categorisation
category_mapping2 = {
    'NoCopyrightSounds': 'Diverse',
    'Dua Lipa': 'Young Adults',
    'Queen Official': 'Diverse',
    'Little Mix': 'Young Adults',
    'Jessie J': 'Diverse',
    'Gorillaz': 'Young Adults',
    'The Beatles': 'Diverse',
    'Passenger': 'Diverse',
    'Mark Ronson': 'Young Adults',
    'UKF Dubstep': 'Young Adults',
    'Capital FM': 'Young Adults',
    'James Arthur': 'Young Adults',
    'GRM Daily': 'Young Adults',
    'DanTDM': 'Young Adults',
    'KSI': 'Young Adults',
    'Ali-A': 'Young Adults',
    'Sidemen': 'Young Adults',
    'JJ Olatunji': 'Diverse',
    'Syndicate': 'Young Adults',
    'Mumbo Jumbo': 'Young Adults',
    'Grian': 'Young Adults',
    'Daz Games': 'Young Adults',
    'Vikkstar123': 'Young Adults',
    'The Yogscast': 'Young Adults',
    'LDShadowLady': 'Young Adults',
    'TommyInnit': 'Young Adults',
    'Morgz': 'Young Adults',
    'Wilbur Soot': 'Young Adults',
    'Behzinga': 'Young Adults',
    'Wisp': 'Young Adults',
    'WillNE': 'Young Adults',
    'Zerkaa': 'Young Adults',
    'Mister Max': 'Kids',
    'Jelly': 'Young Adults',
    'Miss Katy': 'Kids',
    'Dan Rhodes': 'Young Adults',
    'Gaby and Alex': 'Kids',
    'MoreSidemen': 'Young Adults',
    'MessYourself': 'Young Adults',
    'Russell Brand': 'Diverse',
    'Niko Omilana': 'Young Adults',
    'Joe Weller': 'Diverse',
    'Jeremy Lynch': 'Diverse',
    'TomSka': 'Diverse',
    'Rhia Official': 'Diverse',
    'DisneyChannelUK': 'Kids',
    'Disney Kids': 'Kids',
    'Emily Tube': 'Kids',
    'Slogo': 'Diverse',
    'Sing King': 'Diverse',
    'Woody & Kleiny': 'Young Adults',
    'Jungle Beat': 'Kids',
    'Shaun the Sheep Official': 'Kids',
    'Cartoons for Kids': 'Kids',
    'Moonbug Kids - Kids Learning Videos': 'Kids',
    'PlayToys': 'Kids',
    'ARPO The Robot': 'Kids',
    'RubyandBonnie': 'Kids',
    'Nickelodeon UK': 'Kids',
    'Pingu - Official Channel': 'Kids',
    'Tiana2': 'Kids',
    'WildBrain Kids': 'Kids',
    'Max and Katy': 'Kids',
    'TheDadLab': 'Kids',
    'English with Lucy': 'Diverse',
    'BBC Learning English': 'Diverse',
    'BBC News': 'Diverse',
    'BBC News عربي': 'Diverse',
    '24 News HD': 'Diverse',
    'Sky News': 'Diverse',
    'BBC Radio 1': 'Diverse',
    'CGP Grey': 'Diverse',
    'Thoughty2': 'Diverse',
    'Real Stories': 'Diverse',
    'Boomerang UK': 'Diverse',
    'F2Freestylers - Ultimate Soccer Skills Channel': 'Diverse',
    'Liverpool FC': 'Diverse',
    'Manchester United': 'Diverse',
    'Man City': 'Diverse',
    'colinfurze': 'Diverse',
    'Mrwhosetheboss': 'Diverse',
    'Mrwhosetheboss Shorts': 'Diverse',
    'carwow': 'Diverse',
    'Top Gear': 'Diverse',
    'Jamie Oliver': 'Diverse',
    'Classic Mr Bean': 'Diverse',
    'Space Videos': 'Diverse',
    'The X Factor UK': 'Diverse',
    "Simon's Cat": 'Diverse',
    'Ben Phillips': 'Diverse',
    'Dumori Bay': 'Diverse',
    'TGFbro': 'Diverse',
    'Jarvis': 'Diverse',
    'Roxxsaurus': 'Diverse',
    'BBC': 'Diverse',
    'Awakening Music': 'Diverse',
    'Tiana': 'Adults',
    'Julius Dein': 'Diverse',
    'ChrisMD': 'Diverse',
    'More Emily': 'Kids'
}

# Creating the Likely target audience' column by mapping the 'Channel_name' column
final_merged_df['Channel_target_audience'] = final_merged_df['Channel_name'].map(category_mapping2)

# %%
final_merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   #                        100 non-null    int64
#  1   NOMBRE                   100 non-null    object
#  2   SEGUIDORES               100 non-null    object
#  3   TP                       100 non-null    object
#  4   PAÍS                     100 non-null    object
#  5   TEMA DE INFLUENCIA       9 non-null      object
#  6   ALCANCE POTENCIAL        100 non-null    object
#  7   GUARDAR                  0 non-null      float64
#  8   INVITAR A LA CAMPAÑA     100 non-null    object
#  9   Channel_ID               100 non-null    object
#  10  Channel_name             100 non-null    object
#  11  Subscribers              100 non-null    int64
#  12  Views                    100 non-null    int64
#  13  Total_videos             100 non-null    int64
#  14  Video_views              100 non-null    int64
#  15  Total_likes              100 non-null    int64
#  16  Total_comments           100 non-null    int64
#  17  Engagement_rate          100 non-null    float64
#  18  Channel_category         100 non-null    object
#  19  Channel_target_audience  100 non-null    object
# dtypes: float64(2), int64(7), object(11)
# memory usage: 15.8+ KB

# %%
final_merged_df
# Out:
#       #                                       NOMBRE SEGUIDORES    TP  \
# 0     1  NoCopyrightSounds @UC_aEa8K-EOJ3D6gOs7HcyNg      32.9M     -
# 1     2             DanTDM @UCS5Oz6CHmeoF7vSad0qqXfw      26.3M     -
# 2     3                KSI @UCVtFOytbRpEvzLjvqGG5gxQ        24M     -
# 3     4         Mister Max @UC_8PAD0Qmi6_gpe77S1Atgg        23M  0.1%
# 4     5              Jelly @UC0DZmkupLYwc0yDsfocLh0A      22.9M     -
# ..  ...                                          ...        ...   ...
# 95   96               Wisp @UC0h07r_UgTD0Tc-Dn5XLX3g       4.7M  1.1%
# 96   97             WillNE @UCaFUrR3oSxOl5Y9y6tvLTEg       4.7M  2.4%
# 97   98             Zerkaa @UChntGq8THlUokhc1tT-M2wA       4.7M  2.3%
# 98   99       Ben Phillips @UChoQQRDf-zU1h6_YjKkWvdw       4.6M     -
# 99  100         Roxxsaurus @UCBKFH7bU2ebvO68FtuGjyyw       4.5M     -
#
#                 PAÍS TEMA DE INFLUENCIA ALCANCE POTENCIAL  GUARDAR  \
# 0        Reino Unido             Música              9.9M      NaN
# 1        Reino Unido                NaN              7.9M      NaN
# 2        Reino Unido                NaN              7.2M      NaN
# 3        Reino Unido                NaN              6.9M      NaN
# 4        Reino Unido                NaN              6.9M      NaN
# ..               ...                ...               ...      ...
# 95  संयुक्त अधिराज्य                NaN              1.4M      NaN
# 96  संयुक्त अधिराज्य                NaN              1.4M      NaN
# 97  संयुक्त अधिराज्य                NaN              1.4M      NaN
# 98  संयुक्त अधिराज्य                NaN              1.4M      NaN
# 99  संयुक्त अधिराज्य                NaN              1.4M      NaN
#
#    INVITAR A LA CAMPAÑA                Channel_ID       Channel_name  \
# 0            Ver Perfil  UC_aEa8K-EOJ3D6gOs7HcyNg  NoCopyrightSounds
# 1            Ver Perfil  UCS5Oz6CHmeoF7vSad0qqXfw             DanTDM
# 2            Ver Perfil  UCVtFOytbRpEvzLjvqGG5gxQ                KSI
# 3            Ver Perfil  UC_8PAD0Qmi6_gpe77S1Atgg         Mister Max
# 4            Ver Perfil  UC0DZmkupLYwc0yDsfocLh0A              Jelly
# ..                  ...                       ...                ...
# 95      प्रोफ़ाइल देखें  UC0h07r_UgTD0Tc-Dn5XLX3g               Wisp
# 96      प्रोफ़ाइल देखें  UCaFUrR3oSxOl5Y9y6tvLTEg             WillNE
# 97      प्रोफ़ाइल देखें  UChntGq8THlUokhc1tT-M2wA             Zerkaa
# 98      प्रोफ़ाइल देखें  UChoQQRDf-zU1h6_YjKkWvdw       Ben Phillips
# 99      प्रोफ़ाइल देखें  UCBKFH7bU2ebvO68FtuGjyyw         Roxxsaurus
#
#     Subscribers        Views  Total_videos  Video_views  Total_likes  \
# 0      33700000  11118688310          1665   8811525686    127750487
# 1      28700000  19824733776          3707   4485378087     82952541
# 2      24100000   6015064768          1252   2742462970     72052069
# 3      24500000  16070336960          1145  11674024737     52024145
# 4      23600000  15083492903          6422   1159697546     38797656
# ..          ...          ...           ...          ...          ...
# 95      5210000   1085810664           524   1031701063     29622855
# 96      5040000    858661214           305    857703590     38033559
# 97      4710000    858247303          2021    321415000     16856388
# 98      4540000   1274000926           860    658327787     19019161
# 99      4580000    541841284           950    312090851      9916635
#
#     Total_comments  Engagement_rate Channel_category Channel_target_audience
# 0          4278814         1.498370    Music/Artists                 Diverse
# 1          8510510         2.039138    Gaming/Gamers            Young Adults
# 2          5752656         2.837038    Gaming/Gamers            Young Adults
# 3           292147         0.448143  Comedy/Vloggers                    Kids
# 4           992799         3.431106  Comedy/Vloggers            Young Adults
# ..             ...              ...              ...                     ...
# 95         1056463         2.973664    Gaming/Gamers            Young Adults
# 96         1357639         4.592635    Gaming/Gamers            Young Adults
# 97          376554         5.361586    Gaming/Gamers            Young Adults
# 98         1509130         3.118248    Entertainment                 Diverse
# 99          394087         3.303757    Miscellaneous                 Diverse
#
# [100 rows x 20 columns]

# %%
# Converting DataFrame to csv
final_merged_df.to_csv('youtube_data_py.csv', index=False)

# %%
# !pip install sqlalchemy -q

# %%
# !pip install pymysql -q

# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql

# Read the CSV file
df = pd.read_csv('C:\\Users\\dadar\\PortfolioProject\\youtube_data_py.csv')

# Create an engine and connect to the MySQL database
engine = create_engine('mysql+pymysql://root:mylovelyMOM@119@localhost/youtube_db')

# Write the data to the table
df.to_sql('top_uk_youtubers_2024', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\anaconda3\envs\YT-env\Lib\site-packages\pymysql\connections.py:649, in Connection.connect(self, sock)
#     648 try:
# --> 649     sock = socket.create_connection(
#     650         (self.host, self.port), self.connect_timeout, **kwargs
#     651     )
#     652     break
#
# File ~\anaconda3\envs\YT-env\Lib\socket.py:827, in create_connection(address, timeout, source_address, all_errors)
#     826 exceptions = []
# --> 827 for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     828     af, socktype, proto, canonname, sa = res
#
# File ~\anaconda3\envs\YT-env\Lib\socket.py:962, in getaddrinfo(host, port, family, type, proto, flags)
#     961 addrlist = []
# --> 962 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     963     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11003] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\envs\YT-env\Lib\site-packages\sqlalchemy\engine\base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\sqlalchemy\engine\base.py:3300, in Engine.raw_connection(self)
#    3279 """Return a "raw" DBAPI connection from the connection pool.
#    3280
#    3281 The returned object is a proxied version of the DBAPI
#    (...)
#    3298
#    3299 """
# -> 3300 return self.pool.connect()
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
#     444 The connection is instrumented such that when its
#    (...)
#     447
#     448 """
# --> 449 return _ConnectionFairy._checkout(self)
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\sqlalchemy\pool\base.py:1263, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1262 if not fairy:
# -> 1263     fairy = _ConnectionRecord.checkout(pool)
#    1265     if threadconns is not None:
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\sqlalchemy\pool\base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\sqlalchemy\pool\impl.py:179, in QueuePool._do_get(self)
#     178 except:
# --> 179     with util.safe_reraise():
#     180         self._dec_overflow()
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     176 try:
# --> 177     return self._create_connection()
#     178 except:
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\sqlalchemy\pool\base.py:390, in Pool._create_connection(self)
#     388 """Called by subclasses to create a new ConnectionRecord."""
# --> 390 return _ConnectionRecord(self)
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\sqlalchemy\pool\base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\sqlalchemy\pool\base.py:900, in _ConnectionRecord.__connect(self)
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\sqlalchemy\pool\base.py:896, in _ConnectionRecord.__connect(self)
#     895 self.starttime = time.time()
# --> 896 self.dbapi_connection = connection = pool._invoke_creator(self)
#     897 pool.logger.debug("Created new connection %r", connection)
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\sqlalchemy\engine\create.py:643, in create_engine.<locals>.connect(connection_record)
#     641             return connection
# --> 643 return dialect.connect(*cargs, **cparams)
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\sqlalchemy\engine\default.py:620, in DefaultDialect.connect(self, *cargs, **cparams)
#     618 def connect(self, *cargs, **cparams):
#     619     # inherits the docstring from interfaces.Dialect.connect
# --> 620     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\pymysql\connections.py:361, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, collation, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_key_password, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     360 else:
# --> 361     self.connect()
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\pymysql\connections.py:716, in Connection.connect(self, sock)
#     715         print(exc.traceback)
# --> 716     raise exc
#     718 # If e is neither DatabaseError or IOError, It's a bug.
#     719 # But raising AssertionError hides original error.
#     720 # So just reraise it.
#
# OperationalError: (2003, "Can't connect to MySQL server on '119@localhost' ([Errno 11003] getaddrinfo failed)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[6], line 12
#       9 engine = create_engine('mysql+pymysql://root:mylovelyMOM@119@localhost/youtube_db')
#      11 # Write the data to the table
# ---> 12 df.to_sql('top_uk_youtubers_2024', con=engine, if_exists='append', index=False)
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\pandas\core\generic.py:3084, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2886 """
#    2887 Write records stored in a DataFrame to a SQL database.
#    2888
#    (...)
#    3080 [(1,), (None,), (2,)]
#    3081 """  # noqa: E501
#    3082 from pandas.io import sql
# -> 3084 return sql.to_sql(
#    3085     self,
#    3086     name,
#    3087     con,
#    3088     schema=schema,
#    3089     if_exists=if_exists,
#    3090     index=index,
#    3091     index_label=index_label,
#    3092     chunksize=chunksize,
#    3093     dtype=dtype,
#    3094     method=method,
#    3095 )
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\pandas\io\sql.py:841, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     836 elif not isinstance(frame, DataFrame):
#     837     raise NotImplementedError(
#     838         "'frame' argument should be either a Series or a DataFrame"
#     839     )
# --> 841 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
#     842     return pandas_sql.to_sql(
#     843         frame,
#     844         name,
#    (...)
#     853         **engine_kwargs,
#     854     )
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\pandas\io\sql.py:906, in pandasSQL_builder(con, schema, need_transaction)
#     903     raise ImportError("Using URI string without sqlalchemy installed.")
#     905 if sqlalchemy is not None and isinstance(con, (str, sqlalchemy.engine.Connectable)):
# --> 906     return SQLDatabase(con, schema, need_transaction)
#     908 adbc = import_optional_dependency("adbc_driver_manager.dbapi", errors="ignore")
#     909 if adbc and isinstance(con, adbc.Connection):
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\pandas\io\sql.py:1636, in SQLDatabase.__init__(self, con, schema, need_transaction)
#    1634     self.exit_stack.callback(con.dispose)
#    1635 if isinstance(con, Engine):
# -> 1636     con = self.exit_stack.enter_context(con.connect())
#    1637 if need_transaction and not con.in_transaction():
#    1638     self.exit_stack.enter_context(con.begin())
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\sqlalchemy\engine\base.py:3276, in Engine.connect(self)
#    3253 def connect(self) -> Connection:
#    3254     """Return a new :class:`_engine.Connection` object.
#    3255
#    3256     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3273
#    3274     """
# -> 3276     return self._connection_cls(self)
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\sqlalchemy\engine\base.py:148, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     146         self._dbapi_connection = engine.raw_connection()
#     147     except dialect.loaded_dbapi.Error as err:
# --> 148         Connection._handle_dbapi_exception_noconnection(
#     149             err, dialect, engine
#     150         )
#     151         raise
#     152 else:
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\sqlalchemy\engine\base.py:2440, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2438 elif should_wrap:
#    2439     assert sqlalchemy_exception is not None
# -> 2440     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2441 else:
#    2442     assert exc_info[1] is not None
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\sqlalchemy\engine\base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 if connection is None:
#     145     try:
# --> 146         self._dbapi_connection = engine.raw_connection()
#     147     except dialect.loaded_dbapi.Error as err:
#     148         Connection._handle_dbapi_exception_noconnection(
#     149             err, dialect, engine
#     150         )
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\sqlalchemy\engine\base.py:3300, in Engine.raw_connection(self)
#    3278 def raw_connection(self) -> PoolProxiedConnection:
#    3279     """Return a "raw" DBAPI connection from the connection pool.
#    3280
#    3281     The returned object is a proxied version of the DBAPI
#    (...)
#    3298
#    3299     """
# -> 3300     return self.pool.connect()
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
#     441 def connect(self) -> PoolProxiedConnection:
#     442     """Return a DBAPI connection from the pool.
#     443
#     444     The connection is instrumented such that when its
#    (...)
#     447
#     448     """
# --> 449     return _ConnectionFairy._checkout(self)
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\sqlalchemy\pool\base.py:1263, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1255 @classmethod
#    1256 def _checkout(
#    1257     cls,
#    (...)
#    1260     fairy: Optional[_ConnectionFairy] = None,
#    1261 ) -> _ConnectionFairy:
#    1262     if not fairy:
# -> 1263         fairy = _ConnectionRecord.checkout(pool)
#    1265         if threadconns is not None:
#    1266             threadconns.current = weakref.ref(fairy)
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\sqlalchemy\pool\base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     710     rec = cast(_ConnectionRecord, pool._do_get())
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#     715     dbapi_connection = rec.get_connection()
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\sqlalchemy\pool\impl.py:179, in QueuePool._do_get(self)
#     177     return self._create_connection()
#     178 except:
# --> 179     with util.safe_reraise():
#     180         self._dec_overflow()
#     181     raise
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     175 if self._inc_overflow():
#     176     try:
# --> 177         return self._create_connection()
#     178     except:
#     179         with util.safe_reraise():
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\sqlalchemy\pool\base.py:390, in Pool._create_connection(self)
#     387 def _create_connection(self) -> ConnectionPoolEntry:
#     388     """Called by subclasses to create a new ConnectionRecord."""
# --> 390     return _ConnectionRecord(self)
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\sqlalchemy\pool\base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     672 self.__pool = pool
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\sqlalchemy\pool\base.py:900, in _ConnectionRecord.__connect(self)
#     898     self.fresh = True
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#     902 else:
#     903     # in SQLAlchemy 1.4 the first_connect event is not used by
#     904     # the engine, so this will usually not be set
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\sqlalchemy\pool\base.py:896, in _ConnectionRecord.__connect(self)
#     894 try:
#     895     self.starttime = time.time()
# --> 896     self.dbapi_connection = connection = pool._invoke_creator(self)
#     897     pool.logger.debug("Created new connection %r", connection)
#     898     self.fresh = True
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\sqlalchemy\engine\create.py:643, in create_engine.<locals>.connect(connection_record)
#     640         if connection is not None:
#     641             return connection
# --> 643 return dialect.connect(*cargs, **cparams)
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\sqlalchemy\engine\default.py:620, in DefaultDialect.connect(self, *cargs, **cparams)
#     618 def connect(self, *cargs, **cparams):
#     619     # inherits the docstring from interfaces.Dialect.connect
# --> 620     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\pymysql\connections.py:361, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, collation, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_key_password, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     359     self._sock = None
#     360 else:
# --> 361     self.connect()
#
# File ~\anaconda3\envs\YT-env\Lib\site-packages\pymysql\connections.py:716, in Connection.connect(self, sock)
#     714     if DEBUG:
#     715         print(exc.traceback)
# --> 716     raise exc
#     718 # If e is neither DatabaseError or IOError, It's a bug.
#     719 # But raising AssertionError hides original error.
#     720 # So just reraise it.
#     721 raise
#
# OperationalError: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '119@localhost' ([Errno 11003] getaddrinfo failed)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
